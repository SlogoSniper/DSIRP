# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False
 # True

# %%
def dict_to_list(dict):
    dict_list = list(dict.items())
    return dict_list

# %%
is_anagram('tachymetric', 'mccarthyite') # True

# %%
is_anagram('post', 'top') # False, letter not present

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies

# %%
is_anagram('top', 'post') # False, letters left over at the end

# %%
is_anagram('topss', 'postt') # False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False


def all_anagram_pairs(word_list):
    word_count = len(word_list)
    i = 0
    pairs = []

    while i != word_count:
        checking = word_list[i]
        for word in word_list:
            if word == checking:
                continue
            elif is_anagram(checking, word):
                pairs.append((checking, word))
        i += 1
    
    pair_count = len(pairs)
        
        
    return pairs

all_anagram_pairs(short_word_list)

# %%
all_anagram_pairs(short_word_list)

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
# pairs = all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    anagrams = {}

    # Loop over the list of words
    for word in word_list:
        # Rearrange the word so that each letter is in alphabetical order 
        sorted_word = ''.join(sorted(word))
        # Check if the resorted word is already a key in the dictionary 
        if not anagrams.get(sorted_word):
            # Create a key with the resorted word if it is not and add the normal unsorted word as a value
            anagrams.update({sorted_word: [1, word]})
        else:
            # Just add the unsorted word as a value to the already existing key
            anagrams[sorted_word].append(word)
            anagrams[sorted_word][0] += 1
    
    # Turn the dictionary into a list of tuples
    anagrams_list = list(anagrams.items())
    length = len(anagrams_list) - 1    
    # Save the list
    store_anagrams_list = anagrams_list
    # Loop through the list for each element in anagrams_list:
    while length != -1:
        # If length of the second value of the tuple is 1 then remove it from the list
        if anagrams_list[length][1][0] == 1:
            store_anagrams_list.remove(anagrams_list[length])
            length -= 1
        else:
            # Clean up the list by removing coutner element
            del store_anagrams_list[length][1][0]
            length -= 1
        
    # Turn the list back into a dictionary        
    true_anagrams = {ele[0] : ele[1]  for ele in store_anagrams_list}
    # Return the dictionary
    return true_anagrams

# %%
all_anagram_lists(word_list)
# Out:
# {'eikps': ['spike', 'pikes'],
#  "'achissty": ["chasity's", "scythia's"],
#  "'ailsss": ["sisal's", "silas's"],
#  'cefgiinrty': ['certifying', 'rectifying'],
#  'aelmnst': ['laments', 'mantles', 'mantels'],
#  "'aeilss": ["aisle's", "elias's", "elisa's"],
#  'dgimnoo': ['domingo', 'dooming'],
#  'aeln': ['neal', 'lane', 'lean', 'lena'],
#  "'eeilmnosst": ["milestone's", "limestone's"],
#  'acdesu': ['sauced', 'caused'],
#  'eeirrt': ['retire', 'terrie'],
#  'aessss': ['assess', 'sasses'],
#  'adm': ['dam', 'amd', 'mad'],
#  'adefilnot': ['defoliant', 'deflation'],
#  'degins': ['signed', 'deigns', 'design', 'singed'],
#  'abelm': ['blame', 'amble', 'mable', 'melba', 'mabel'],
#  'abcdeemr': ['cambered', 'embraced'],
#  'aelqsu': ['equals', 'squeal'],
#  'adekst': ['skated', 'tasked', 'staked'],
#  'eeinqru': ['enquire', 'enrique'],
#  'adeknr': ['darken', 'ranked', 'danker', 'narked', 'kendra'],
#  'adilv': ['vidal', 'valid', 'advil'],
#  "'abgrs": ["brag's", "garb's", "grab's"],
#  'adegnrt': ['dragnet', 'granted'],
#  'denorsw': ['wonders', 'downers'],
#  'aghs': ['gash', 'hags', 'shag'],
#  'aacllsuy': ['causally', 'casually'],
#  'acepr': ['recap', 'caper', 'crape'],
#  "'bekoors": ["booker's", "brooke's"],
#  'how': ['how', 'who'],
#  'delw': ['lewd', 'weld'],
#  'aelnv': ['navel', 'venal'],
#  "'aeimnors": ["moraine's", "romaine's"],
#  'ceikrst': ['rickets', 'tickers', 'sticker'],
#  'blost': ['blots', 'bolts'],
#  'elop': ['lope', 'opel', 'pole'],
#  'aeenntt': ['annette', 'nanette'],
#  'ceinor': ['enrico', 'corine'],
#  'adeilm': ['mailed', 'medial', 'imelda'],
#  'deirrs': ['riders', 'driers'],
#  "'dis": ["di's", "id's"],
#  'eiinprs': ['inspire', 'spinier'],
#  'aels': ['lesa', 'leas', 'seal', 'sale', 'elsa', 'ales'],
#  'aghimns': ['shaming', 'mashing'],
#  "'aeglns": ["angel's", "galen's", "angle's"],
#  'eilmntuy': ['minutely', 'untimely'],
#  'oprstu': ['sprout', 'stupor', 'proust'],
#  'giimnr': ['riming', 'miring'],
#  'ghos': ['hogs', 'gosh'],
#  'abde': ['abed', 'bade', 'bead'],
#  'aceeinrsst': ['ancestries', 'resistance'],
#  "'aacclrsu": ["caracul's", "accrual's"],
#  'aailsv': ['saliva', 'avails'],
#  'enosst': ['onsets', 'stones'],
#  "'abdors": ["broad's", "board's"],
#  'aeprsy': ['payers', 'repays'],
#  'cdinostu': ['conduits', 'discount'],
#  "'egnors": ["goner's", "negro's", "goren's"],
#  "'ikns": ["ink's", "kin's"],
#  'adeilmst': ['medalist', 'misdealt'],
#  "'aeelss": ["easel's", "lease's"],
#  'deilw': ['wield', 'wilde', 'wiled'],
#  'cceeginort': ['egocentric', 'geocentric'],
#  'adeglr': ['glared', 'gerald'],
#  'glpsu': ['plugs', 'gulps'],
#  "'acenos": ["canoe's", "ocean's"],
#  "'hoosst": ["shoot's", "sooth's"],
#  'ehirs': ['sheri', 'hires', 'shire', 'heirs'],
#  "'acdemors": ["mercado's", "comrade's"],
#  "'adirsy": ["diary's", "dairy's"],
#  "'ehorst": ["other's", "throe's"],
#  'cinos': ['sonic', 'icons', 'coins', 'scion'],
#  'emno': ['nome', 'omen'],
#  'eilps': ['plies', 'spiel', 'piles'],
#  'aeilnort': ['relation', 'oriental'],
#  'aegrs': ['rages', 'gears', 'sager'],
#  'deeimrt': ['mitered', 'demerit', 'merited'],
#  'dddeil': ['diddle', 'lidded'],
#  'iklns': ['kilns', 'slink', 'links'],
#  'deeotv': ['vetoed', 'devote'],
#  'elorss': ['losers', 'lessor'],
#  'aegsst': ['stages', 'sagest'],
#  "'loopss": ["spool's", "sloop's"],
#  'abceefiilrt': ['rectifiable', 'certifiable'],
#  'ademno': ['daemon', 'moaned'],
#  'ilpst': ['spilt', 'split'],
#  'ersttu': ['utters', 'truest'],
#  'ehlstu': ['sleuth', 'hustle'],
#  "'aaillmns": ["alnilam's", "manilla's"],
#  'aelpsst': ['staples', 'pastels'],
#  'aors': ['soar', 'oars', 'rosa'],
#  "'inprstu": ["turpin's", "turnip's"],
#  "'aeills": ["lelia's", "leila's", "allie's"],
#  'eginrs': ['ingres', 'singer', 'signer', 'resign', 'reigns'],
#  'aellps': ['lapels', 'aspell'],
#  'eelrsv': ['levers', 'revels'],
#  'crstuy': ['crusty', 'curtsy'],
#  "'behirrst": ["rebirth's", "birther's"],
#  'elorsw': ['slower', 'rowels', 'lowers'],
#  'ceoprss': ['process', 'corpses'],
#  'aceilnor': ['cornelia', 'caroline'],
#  'ghirt': ['girth', 'right'],
#  'adelnr': ['lander', 'lenard'],
#  'bnsu': ['buns', 'nubs', 'snub'],
#  'diov': ['void', 'ovid'],
#  'ahlu': ['haul', 'hula'],
#  'adeilprs': ['spiraled', 'lipreads'],
#  "'aelst": ["teal's", "leta's", "tale's"],
#  'aginpv': ['vaping', 'paving'],
#  'aegiln': ['linage', 'genial'],
#  'ceoorstuu': ['outsource', 'courteous'],
#  'deeirrs': ['dreiser', 'serried'],
#  'aeemnsst': ['massenet', 'tameness'],
#  "'orsty": ["troy's", "tyro's", "tory's"],
#  'aelry': ['early', 'layer', 'leary', 'relay'],
#  'chklosy': ['shlocky', 'shylock'],
#  "'eeirs": ["erie's", "eire's"],
#  'eirss': ['rises', 'sires'],
#  'aeegr': ['agree', 'eager'],
#  'deimr': ['dimer', 'rimed', 'mired'],
#  'einps': ['snipe', 'spine', 'pines', 'penis'],
#  'eemort': ['meteor', 'remote'],
#  'aderst': ['treads', 'trades', 'stared'],
#  'dghiins': ['shindig', 'dishing'],
#  'celnoos': ['console', 'colones'],
#  'einrss': ['sirens', 'resins', 'rinses'],
#  'efinr': ['infer', 'finer'],
#  'aarstt': ['tatars', 'strata'],
#  'aekrst': ['takers', 'skater', 'streak'],
#  "'aimns": ["mani's", "main's"],
#  'dginnosu': ['undoings', 'sounding'],
#  'anoprt': ['patron', 'tarpon'],
#  'ahmss': ['smash', 'shams'],
#  "'adeegnrs": ["grandee's", "grenade's"],
#  'eeinrstu': ['retinues', 'reunites'],
#  'eggilrsw': ['wigglers', 'wriggles'],
#  'ceikorst': ['stockier', 'rockiest'],
#  "'eelps": ["peel's", "pele's"],
#  "'oss": ["os's", "so's"],
#  'aars': ['sara', 'saar'],
#  "'adelrs": ["alder's", "adler's"],
#  'aesv': ['vase', 'save'],
#  "'bgos": ["bog's", "gob's"],
#  'eint': ['nite', 'tine'],
#  'aegiinnprt': ['repainting', 'pertaining'],
#  'aett': ['teat', 'etta', 'tate'],
#  'bdennrsuu': ['unburdens', 'sunburned'],
#  'agsw': ['wags', 'swag'],
#  "'aelps": ["plea's", "pale's", "peal's", "leap's"],
#  'acelosv': ['coevals', 'alcoves'],
#  "'ehoss": ["hose's", "shoe's"],
#  'deil': ['idle', 'deli', 'lied'],
#  'acdeelr': ['cleared', 'declare'],
#  'acden': ['caned', 'dance'],
#  'apt': ['tap', 'apt', 'pat'],
#  'ceginorst': ['escorting', 'corseting'],
#  'aprs': ['raps', 'spar', 'pars', 'rasp'],
#  'adenpp': ['append', 'napped'],
#  "'aensv": ["evan's", "nave's", "neva's", "vane's"],
#  'eginrstw': ['wresting', 'strewing'],
#  "'benorst": ["bronte's", "breton's"],
#  "'ehlls": ["hell's", "she'll"],
#  'eeprs': ['peers', 'spree', 'speer'],
#  'aelrt': ['later', 'alter', 'alert'],
#  'abst': ['tabs', 'stab', 'bast', 'bats'],
#  'addelsw': ['swaddle', 'dawdles', 'waddles'],
#  "'aansssu": ["susana's", "nassau's"],
#  'abdors': ['broads', 'boards'],
#  'elmost': ['motels', 'molest'],
#  'aceprs': ['capers', 'recaps', 'crapes', 'parsec', 'scrape'],
#  'eeeprsw': ['sweeper', 'weepers'],
#  'aeorsu': ['arouse', 'roseau'],
#  'aegnrst': ['strange', 'sargent', 'garnets'],
#  "'efmorrs": ["former's", "reform's"],
#  'acdeeinorst': ['desecration', 'considerate'],
#  "'einrs": ["rein's", "erin's"],
#  "'lmpsu": ["plum's", "lump's"],
#  'aeersst': ['easters', 'teasers'],
#  'eeglnst': ['gentles', 'stengel'],
#  "'abeerst": ["beater's", "rebate's"],
#  'belo': ['bole', 'lobe'],
#  'aeilrs': ['serial', 'israel'],
#  "'aeeijnns": ["jeanine's", "jeannie's"],
#  "'brsu": ["bur's", "rub's"],
#  'eeforrsst': ['reforests', 'foresters'],
#  "'ilnos": ["loin's", "olin's", "lion's"],
#  "'gstu": ["tug's", "gut's"],
#  'alsst': ['slats', 'lasts', 'salts'],
#  'cdeeoprrsu': ['procedures', 'reproduces'],
#  'gipr': ['grip', 'prig'],
#  'cersttu': ['curtest', 'cutters'],
#  "'ehnorst": ["theron's", "hornet's", "throne's"],
#  'eefilrs': ['reliefs', 'refiles'],
#  'eimprstu': ['stumpier', 'impurest'],
#  'giillnt': ['lilting', 'tilling'],
#  'adeiln': ['alined', 'nailed', 'denial', 'daniel'],
#  'ehmorst': ['thermos', 'mothers', 'smother'],
#  'aceilmst': ['clematis', 'climates'],
#  'aehnns': ['hansen', 'hennas'],
#  "'aelnrstu": ["renault's", "neutral's", "laurent's"],
#  'aenrst': ['sterna', 'astern'],
#  "'dginos": ["doing's", "dingo's"],
#  'aacinr': ['carina', 'crania'],
#  'aehks': ['hakes', 'shake'],
#  'bcehrstu': ['schubert', 'butchers'],
#  "'bbcelors": ["clobber's", "cobbler's"],
#  'cdeiinnoorst': ['reconditions', 'conditioners'],
#  "'abnrs": ["barn's", "bran's"],
#  'aeprt': ['petra', 'prate', 'taper', 'apter'],
#  "'acstt": ["tact's", "catt's"],
#  'aamrstu': ['traumas', 'sumatra'],
#  'dehirst': ['shirted', 'dithers'],
#  "'adells": ["della's", "ladle's"],
#  'ceopss': ['copses', 'scopes'],
#  'eginrst': ['resting', 'stinger'],
#  'eginnss': ['ensigns', 'sensing'],
#  'aeglr': ['elgar', 'large', 'alger', 'lager', 'glare', 'regal'],
#  'aeinrt': ['retina', 'retain'],
#  "'acckosss": ["cossack's", "cassock's"],
#  'eikrst': ['strike', 'trikes'],
#  "'ahmss": ["sham's", "mash's"],
#  'aclrsw': ['scrawl', 'crawls'],
#  'aehirssttw': ['sweatshirt', 'swarthiest'],
#  'agillnott': ['totalling', 'allotting'],
#  'dggginru': ['drugging', 'grudging'],
#  'cilo': ['clio', 'loci', 'coil'],
#  'adinrw': ['inward', 'darwin'],
#  'emrsu': ['remus', 'serum'],
#  'abbbgiln': ['blabbing', 'babbling'],
#  'nosy': ['nosy', 'sony'],
#  "'acost": ["taco's", "cato's", "coat's"],
#  "'deeinrssst": ["dissenter's", "tiredness's"],
#  'aeehirstt': ['earthiest', 'heartiest'],
#  'abens': ['beans', 'banes'],
#  'aeknrst': ['tankers', 'rankest'],
#  'aorst': ['astor', 'roast', 'taros', 'sarto', 'sorta'],
#  "'aiinnorstu": ["ruination's", "urination's"],
#  "'eersstt": ["setter's", "street's", "tester's"],
#  'defiiln': ['infield', 'infidel'],
#  'ceinprs': ['pincers', 'princes'],
#  'efhiinrs': ['refinish', 'finisher'],
#  'deiklns': ['kindles', 'slinked'],
#  'adeegnrs': ['deranges', 'grandees', 'grenades'],
#  'aekottu': ['outtake', 'takeout'],
#  'eellrt': ['teller', 'retell'],
#  "'achsty": ["cathy's", "yacht's"],
#  'aegs': ['sage', 'ages', 'sega'],
#  'ceeprsst': ['specters', 'respects', 'scepters'],
#  'abdey': ['bayed', 'beady'],
#  'aehrss': ['shears', 'shares', 'rashes'],
#  'acprs': ['carps', 'scrap', 'craps'],
#  "'ceehiknrst": ["kitchener's", "thickener's"],
#  'aeelmnss': ['lameness', 'maleness', 'nameless', 'salesmen'],
#  'deilp': ['plied', 'piled'],
#  'ellovy': ['volley', 'lovely'],
#  'adeilst': ['details', 'dilates'],
#  'estw': ['stew', 'west', 'wets'],
#  'eimntu': ['minute', 'minuet'],
#  'cllsu': ['culls', 'scull'],
#  'ghnostu': ['noughts', 'shotgun', 'gunshot'],
#  'anor': ['oran', 'arno', 'roan', 'nora', 'aron'],
#  'aelnru': ['neural', 'lauren', 'unreal'],
#  'aginst': ['sating', 'giants'],
#  'beirst': ['tribes', 'bestir'],
#  'ggiilnns': ['slinging', 'singling'],
#  'aehls': ['heals', 'leash', 'shale', 'sahel', 'hales'],
#  'abekr': ['brake', 'baker', 'break'],
#  'beor': ['ebro', 'robe', 'boer', 'bore'],
#  'deeirrt': ['retired', 'tireder', 'retried'],
#  'aaeemnt': ['emanate', 'enemata', 'manatee'],
#  'acinopt': ['caption', 'pontiac'],
#  "'aaceirsv": ["caviare's", "avarice's"],
#  'deorst': ['dorset', 'stored', 'strode', 'sorted'],
#  'ademn': ['medan', 'amend', 'admen', 'named'],
#  'eefiirst': ['feistier', 'fieriest'],
#  'beglrsu': ['burgles', 'buglers'],
#  "'aelnorss": ["salerno's", "orleans's"],
#  'aadin': ['naiad', 'diana', 'nadia'],
#  'cefiklr': ['flicker', 'fickler'],
#  "'aghilmorst": ["logarithm's", "algorithm's"],
#  'aeiprsu': ['piraeus', 'upraise'],
#  'eersst': ['resets', 'serest', 'esters', 'steers'],
#  'adeegnr': ['grandee', 'angered', 'grenade', 'derange', 'enraged'],
#  'amorsy': ['morays', 'mayors'],
#  'lnoos': ['loons', 'solon', 'olson'],
#  'deilnstu': ['unlisted', 'insulted'],
#  'aeilns': ['alines', 'aliens', 'saline'],
#  'belorsst': ['bolsters', 'lobsters'],
#  'acdegln': ['clanged', 'glanced'],
#  'eeirstt': ['testier', 'trieste'],
#  "'adenss": ["sedan's", "sedna's", "andes's", "snead's"],
#  'belmstu': ['stumble', 'tumbles'],
#  "'ggiknos": ["gingko's", "ginkgo's"],
#  'dnosy': ['dyson', 'synod'],
#  'acgiinnotu': ['auctioning', 'cautioning'],
#  'aimn': ['main', 'mani'],
#  'elops': ['poles', 'lopes', 'slope'],
#  "'eglrsu": ["luger's", "gruel's"],
#  "'brstu": ["brut's", "burt's"],
#  'abeglr': ['grable', 'garble'],
#  'agnor': ['argon', 'groan', 'organ'],
#  'defil': ['filed', 'field', 'flied', 'fidel'],
#  'belst': ['blest', 'belts'],
#  'acdenr': ['craned', 'dancer'],
#  'eortv': ['overt', 'voter'],
#  'acdertu': ['traduce', 'decatur'],
#  'ailmrstu': ['altruism', 'muralist'],
#  'deinsty': ['density', 'destiny'],
#  'abtu': ['tabu', 'abut', 'batu', 'tuba'],
#  "'aelsw": ["weal's", "wale's"],
#  'abinry': ['binary', 'brainy'],
#  'aeemnssttt': ['statements', 'testaments'],
#  'bcdeku': ['dubcek', 'bucked'],
#  'eenss': ['sense', 'essen'],
#  'abesst': ['bastes', 'basest', 'beasts'],
#  'abdeelt': ['bleated', 'belated'],
#  'aeeinnoprstt': ['presentation', 'penetrations'],
#  'aceehrt': ['cheater', 'hectare', 'teacher'],
#  'bemoss': ['besoms', 'emboss'],
#  'acks': ['cask', 'sack'],
#  "'aelprsst": ["plaster's", "stapler's", "psalter's"],
#  'enrst': ['rents', 'stern', 'ernst', 'terns'],
#  'aeksst': ['stakes', 'steaks', 'skates'],
#  'giinrs': ['siring', 'rising'],
#  'aacdeglotu': ['catalogued', 'coagulated'],
#  'abdeirss': ['sidebars', 'seabirds'],
#  "'celsu": ["clue's", "luce's"],
#  'irstw': ['writs', 'wrist'],
#  'eggilns': ['niggles', 'negligs', 'leggins'],
#  "'aeemnssttt": ["statement's", "testament's"],
#  'eopss': ['pesos', 'posse', 'poses'],
#  'aaeehhimprtt': ['amphitheatre', 'amphitheater'],
#  'enrrtuu': ['nurture', 'untruer'],
#  'adnw': ['wand', 'dawn'],
#  'aefkr': ['faker', 'freak'],
#  'aagilnv': ['galvani', 'vaginal'],
#  'ddeegin': ['deigned', 'deeding'],
#  'aky': ['kay', 'yak'],
#  "'bhos": ["hbo's", "hob's"],
#  "'abelstt": ["tablet's", "battle's"],
#  'hoops': ['poohs', 'hoops'],
#  'denorsu': ['sounder', 'resound'],
#  'aegimnst': ['steaming', 'mangiest'],
#  'acegilnpr': ['replacing', 'parceling'],
#  'aenrv': ['verna', 'raven'],
#  'aeennrss': ['nearness', 'ensnares'],
#  "'abddeiorss": ["sideboard's", "broadside's"],
#  "'lnooss": ["olson's", "solon's"],
#  'addelnou': ['unloaded', 'duodenal'],
#  'aeinprst': ['pertains', 'painters', 'pantries', 'repaints'],
#  'aegginor': ['georgina', 'georgian'],
#  'celru': ['lucre', 'ulcer', 'cruel'],
#  'aeginnst': ['antigens', 'gentians'],
#  'aeehorrsv': ['overshare', 'overhears'],
#  'egilmmn': ['memling', 'lemming'],
#  'aclm': ['clam', 'calm'],
#  'cenor': ['crone', 'creon'],
#  'cilry': ['cyril', 'lyric'],
#  'hosst': ['hosts', 'shots'],
#  'eilst': ['islet', 'stile', 'tiles'],
#  "'beors": ["boer's", "bore's", "robe's", "ebro's"],
#  "'inst": ["isn't", "nit's", "tin's"],
#  'gnow': ['gown', 'wong'],
#  'chlru': ['lurch', 'churl'],
#  "'enosz": ["zeno's", "zone's"],
#  'aelms': ['males', 'salem', 'lames', 'meals', 'selma'],
#  'eiqtu': ['quite', 'quiet'],
#  "'aaemnsst": ["eastman's", "smetana's"],
#  'bcklnosu': ['unblocks', 'sunblock'],
#  'ddenoru': ['rounded', 'redound'],
#  'ahlsu': ['shula', 'hulas', 'hauls'],
#  'cddeeer': ['decreed', 'receded'],
#  'aenrss': ['snares', 'nasser'],
#  'eprrssuu': ['usurpers', 'pursuers'],
#  'inprtu': ['turnip', 'turpin'],
#  'eerst': ['ester', 'trees', 'reset', 'terse', 'steer'],
#  'orstu': ['torus', 'tours', 'routs'],
#  'inoopt': ['potion', 'option'],
#  "'ellosvy": ["lovely's", "volley's"],
#  'aaginssy': ['gainsays', 'assaying'],
#  'eeersttw': ['tweeters', 'retweets'],
#  'deiorrw': ['rowdier', 'wordier', 'worried'],
#  'deos': ['does', 'odes', 'dose'],
#  "'ehirss": ["shire's", "sheri's"],
#  'ehikt': ['keith', 'kieth'],
#  'als': ['las', 'sal'],
#  'adeeinprt': ['repainted', 'pertained'],
#  'abdehorr': ['harbored', 'abhorred'],
#  'adeehilprs': ['leadership', 'dealership'],
#  "'aceelnrs": ["carlene's", "cleaner's"],
#  'abgrs': ['brags', 'garbs', 'grabs'],
#  'aderrw': ['redraw', 'reward', 'warder', 'warred', 'drawer'],
#  'aimms': ['maims', 'imams'],
#  'egoru': ['rouge', 'rogue'],
#  "'adilsy": ["daily's", "lydia's"],
#  'eeipppr': ['preppie', 'peppier'],
#  'egos': ['goes', 'egos'],
#  'emors': ['romes', 'mores', 'morse'],
#  "'bcesu": ["cebu's", "cube's"],
#  'eilnpsu': ['lupines', 'lineups'],
#  'aelrs': ['reals', 'earls', 'laser'],
#  'addelw': ['dawdle', 'waddle'],
#  "'acnorsy": ["cyrano's", "crayon's"],
#  'eipr': ['pier', 'ripe'],
#  'cdeiorsv': ['discover', 'divorces'],
#  'ceops': ['scope', 'copse', 'copes', 'pecos'],
#  'adgr': ['drag', 'grad'],
#  'em': ['em', 'me'],
#  'deinnst': ['intends', 'indents'],
#  'eelrsstt': ['settlers', 'trestles'],
#  'aennors': ['rosanne', 'roseann'],
#  'acdeinoort': ['coordinate', 'decoration'],
#  'acerst': ['traces',
#   'caster',
#   'reacts',
#   'recast',
#   'caters',
#   'crates',
#   'carets'],
#  'deno': ['deon', 'done', 'node'],
#  'aeehsv': ['heaves', 'sheave'],
#  'acdeilst': ['citadels', 'dialects'],
#  'acnoor': ['corona', 'racoon'],
#  "'aeersst": ["easter's", "teaser's", "teresa's"],
#  'ortt': ['trot', 'tort'],
#  'bginor': ['boring', 'robing'],
#  'aalmnu': ['manual', 'alumna'],
#  'bdeist': ['bidets', 'debits'],
#  "'inps": ["pin's", "nip's"],
#  'acdeeimst': ['medicates', 'decimates'],
#  'aaegstwy': ['gateways', 'getaways'],
#  'hosstu': ['shouts', 'souths'],
#  'abdeirs': ['seabird', 'braised', 'sidebar'],
#  "'hlosst": ["holst's", "sloth's"],
#  'aaeilmnprst': ['paternalism', 'parliaments'],
#  "'aehrs": ["hare's", "hera's", "rhea's"],
#  'adenpps': ['appends', 'snapped'],
#  'aemssu': ['amuses', 'assume'],
#  "'beirs": ["bier's", "brie's"],
#  'ainstu': ['austin', 'unitas'],
#  'accgikln': ['cackling', 'clacking'],
#  "'anorss": ["arson's", "sonar's"],
#  "'aegimrs": ["mirage's", "margie's"],
#  'cdru': ['crud', 'curd'],
#  'beelr': ['rebel', 'berle'],
#  "'adeinns": ["dianne's", "nadine's", "dannie's"],
#  "'cehors": ["roche's", "ochre's", "chore's", "ocher's"],
#  'eefilr': ['relief', 'liefer', 'refile'],
#  'eglo': ['lego', 'ogle', 'loge'],
#  'eilnsv': ['snivel', 'livens'],
#  'cdeeiorrssv': ['discoverers', 'rediscovers'],
#  'bdenorsu': ['rebounds', 'bounders', 'suborned'],
#  'adlnoor': ['rolando', 'orlando'],
#  'deinw': ['wined', 'edwin', 'wendi', 'widen'],
#  'aet': ['ate', 'eat', 'tea', 'eta'],
#  "'orstt": ["trot's", "tort's"],
#  "'eeinrs": ["irene's", "ernie's"],
#  'deginnrsu': ['undersign', 'sundering'],
#  'eeinrsstt': ['triteness', 'interests'],
#  'acddeent': ['decadent', 'decanted'],
#  'abgiknr': ['braking', 'barking'],
#  'aepst': ['paste', 'spate', 'tapes', 'pates', 'septa'],
#  'ginorsu': ['rousing', 'souring'],
#  'dhimoru': ['humidor', 'rhodium'],
#  'adilorty': ['adroitly', 'idolatry', 'dilatory'],
#  "'asswy": ["yaws's", "sway's"],
#  "'deilorss": ["soldier's", "deloris's"],
#  "'adelsy": ["daley's", "delay's"],
#  'accehmno': ['comanche', 'coachmen'],
#  'aagmm': ['magma', 'gamma'],
#  'belorst': ['bolster', 'lobster'],
#  'einops': ['opines', 'ponies'],
#  "'abehss": ["hbase's", "sheba's"],
#  "'deiopsst": ["deposit's", "topside's"],
#  'aaijntu': ['tijuana', 'juanita'],
#  "'adhss": ["dash's", "shad's"],
#  'adilrsz': ['lizards', 'szilard'],
#  'aeimn': ['maine', 'anime'],
#  'eoprss': ['posers', 'spores'],
#  'aelprsy': ['players', 'replays', 'sparely', 'parleys', 'parsley'],
#  "'horst": ["thor's", "roth's"],
#  'moor': ['room', 'moor', 'moro'],
#  'glnsu': ['slung', 'lungs'],
#  'aceirr': ['racier', 'carrie'],
#  'adeimrs': ['admires', 'sidearm', 'misread'],
#  'ceenrt': ['center', 'recent'],
#  "'almps": ["lamp's", "palm's"],
#  'eeirvw': ['review', 'viewer'],
#  'bruy': ['bury', 'ruby'],
#  "'acfiinnorst": ["infraction's", "infarction's"],
#  'aemppr': ['mapper', 'pamper'],
#  'aeeeprrt': ['repeater', 'repartee'],
#  'opstu': ['pouts', 'spout'],
#  "'eorss": ["rose's", "sore's", "eros's"],
#  "'beilrsst": ["bristle's", "blister's"],
#  "'adnors": ["norad's", "radon's", "ronda's", "drano's"],
#  "'adhrsy": ["hydra's", "hardy's"],
#  'adehrt': ['dearth', 'hatred', 'thread'],
#  'achoo': ['ochoa', 'achoo'],
#  'aamss': ['assam', 'amass'],
#  'bnoo': ['bono', 'boon'],
#  'aegmnrs': ['germans', 'mangers'],
#  'aprt': ['rapt', 'part', 'trap', 'tarp'],
#  'oorsst': ['torsos', 'roosts'],
#  "'alpss": ["slap's", "alps's"],
#  'dllory': ['lordly', 'drolly'],
#  'aabls': ['basal', 'balsa'],
#  'aeerrsw': ['wearers', 'swearer'],
#  'ceoprstt': ['prescott', 'protects'],
#  "'cehirs": ["reich's", "erich's", "cheri's"],
#  'apr': ['rap', 'apr', 'par'],
#  'hips': ['hips', 'ship'],
#  'aegilnp': ['leaping', 'pealing'],
#  "'ggiinnss": ["singing's", "signing's"],
#  'acemrs': ['scream', 'creams'],
#  'aalss': ['salsa', 'lassa', 'salas'],
#  "'aadilns": ["danial's", "dalian's"],
#  'acrs': ['scar', 'arcs', 'cars'],
#  'cenorstu': ['counters', 'recounts', 'trounces', 'construe'],
#  "'eflsu": ["flue's", "fuel's"],
#  'eilnos': ['lesion', 'insole'],
#  'ersst': ['rests', 'tress'],
#  "'opst": ["top's", "pot's"],
#  "'blost": ["bolt's", "blot's"],
#  "'eersst": ["ester's", "steer's", "reset's"],
#  'beinrtu': ['tribune', 'turbine'],
#  'adirsu': ['darius', 'radius'],
#  'cdipsu': ['cupids', 'cuspid'],
#  "'aeelstz": ["teazel's", "teazle's"],
#  'ehirssw': ['wishers', 'swisher'],
#  'eirstv': ['rivets', 'strive'],
#  'abdersu': ['earbuds', 'daubers'],
#  "'aelms": ["lame's", "meal's", "elma's", "elam's", "male's"],
#  'achmr': ['march', 'charm'],
#  'acceemnorsttu': ['accoutrements', 'accouterments'],
#  "'eelrsstw": ["wrestle's", "swelter's"],
#  "'eilsv": ["veil's", "evil's", "levi's"],
#  'eimt': ['item', 'time', 'mite', 'emit'],
#  'rstu': ['ruts', 'rust'],
#  "'adeils": ["ideal's", "delia's"],
#  'allosww': ['swallow', 'wallows'],
#  'flnoopssu': ['spoonsful', 'spoonfuls'],
#  'aeilv': ['elvia', 'alive'],
#  'inst': ['nits', 'snit', 'tins'],
#  "'eorrsst": ["resort's", "roster's", "torres's", "sorter's"],
#  "'oprsstu": ["proust's", "sprout's", "stupor's"],
#  'ehilost': ['hostile', 'holiest'],
#  'adeegr': ['geared', 'agreed'],
#  "'aeeglst": ["legate's", "eaglet's"],
#  'efirs': ['fires', 'fries'],
#  'aelnors': ['loaners', 'orleans', 'salerno'],
#  "'dsstuy": ["dusty's", "study's"],
#  "'deinsw": ["edwin's", "wendi's"],
#  "'accefiiinorstt": ["certification's", "rectification's"],
#  'hlost': ['holst', 'sloth'],
#  'cnostu': ['tucson', 'tuscon', 'counts'],
#  'inopt': ['point', 'pinto', 'piton'],
#  "'acst": ["cat's", "act's"],
#  "'chkssu": ["shuck's", "kusch's"],
#  "'emorss": ["morse's", "mores's"],
#  "'achiinst": ["chaitin's", "chianti's"],
#  'deensu': ['ensued', 'endues'],
#  'egoprrsu': ['regroups', 'groupers'],
#  'eopssu': ['opuses', 'spouse'],
#  'egor': ['ergo', 'roeg', 'gore', 'ogre'],
#  'aimprt': ['armpit', 'impart'],
#  "'moprs": ["romp's", "prom's"],
#  'ghirst': ['rights', 'girths'],
#  'aemnrst': ['smarten', 'martens'],
#  'aemrs': ['smear', 'reams', 'mares'],
#  'eoprt': ['trope', 'perot'],
#  'abdrs': ['drabs', 'brads', 'bards'],
#  'acer': ['race', 'care', 'acre'],
#  'ekorrw': ['rework', 'worker'],
#  'aflos': ['foals', 'loafs'],
#  'gimnssu': ['musings', 'mussing'],
#  "'admnos": ["nomad's", "damon's"],
#  'aceginrst': ['recasting', 'caterings'],
#  'closw': ['scowl', 'cowls'],
#  'aaegssu': ['assuage', 'sausage'],
#  'cceinors': ['cornices', 'conciser'],
#  'eikst': ['kites', 'tikes'],
#  "'adehlnsst": ["shetland's", "stendhal's"],
#  'ikmns': ['minks', 'minsk'],
#  'aginprt': ['parting', 'prating'],
#  'adeiiintt': ['initiated', 'dietitian'],
#  "'nrsu": ["run's", "urn's"],
#  'aclopsu': ['copulas', 'cupolas'],
#  'adefil': ['failed', 'afield'],
#  "'esx": ["ex's", "xe's"],
#  "'aimors": ["maori's", "mario's", "moira's"],
#  'aegimrt': ['migrate', 'ragtime', 'maigret'],
#  'aeekortv': ['takeover', 'overtake'],
#  'acdelr': ['cradle', 'calder'],
#  'aalpu': ['palau', 'paula'],
#  'eelnvy': ['evelyn', 'evenly'],
#  "'aerss": ["ares's", "sear's"],
#  'aeipprs': ['sappier', 'apprise'],
#  'aeimnoprttu': ['permutation', 'importunate'],
#  'eenstv': ['steven', 'events'],
#  "'aakoss": ["osaka's", "asoka's"],
#  'deeinr': ['nereid', 'reined', 'denier'],
#  'aemsx': ['exams', 'maxes'],
#  'awy': ['way', 'yaw'],
#  'ailr': ['lair', 'rail', 'lira', 'liar'],
#  'egilnrst': ['ringlets', 'sterling'],
#  'esu': ['use', 'sue'],
#  "'eprsy": ["prey's", "pyre's"],
#  'add': ['dad', 'add'],
#  'ahist': ['thais', 'saith', 'tisha'],
#  'ann': ['nan', 'ann'],
#  'eopsy': ['poesy', 'sepoy'],
#  'bdelloor': ['bordello', 'doorbell'],
#  'deeinrrt': ['interred', 'trendier'],
#  'eellrst': ['tellers', 'retells'],
#  "'ellssw": ["swell's", "wells's"],
#  'achor': ['roach', 'rocha'],
#  "'amnos": ["oman's", "moan's", "mona's"],
#  'adeeprv': ['pervade', 'deprave'],
#  'adinr': ['randi', 'indra', 'drain', 'darin', 'nadir'],
#  'ceikpst': ['pickets', 'skeptic'],
#  "'acensst": ["stance's", "ascent's"],
#  'aelps': ['leaps', 'sepal', 'lapse', 'pales', 'peals', 'pleas'],
#  'egrsu': ['urges', 'surge'],
#  'aginprs': ['sparing', 'parings', 'rasping', 'parsing'],
#  'gghiins': ['higgins', 'sighing'],
#  'celrtuy': ['cruelty', 'cutlery'],
#  "'aelrs": ["lear's", "earl's", "real's"],
#  'adeest': ['teased', 'sedate', 'seated'],
#  'aeeegnrst': ['generates', 'teenagers'],
#  'eginrss': ['signers', 'singers', 'resigns', 'ingress'],
#  "'aaamrss": ["samara's", "asmara's"],
#  'efil': ['file', 'life', 'leif', 'lief'],
#  'deistu': ['duties', 'suited'],
#  "'acinost": ["cation's", "action's"],
#  "'aagrs": ["raga's", "agar's", "agra's"],
#  'berstu': ['buster', 'rebuts', 'brutes', 'tubers'],
#  'acips': ['aspic', 'spica'],
#  'ehost': ['those', 'ethos'],
#  "'anstw": ["want's", "wasn't"],
#  'acginrsv': ['cravings', 'carvings'],
#  'adegrr': ['gerard', 'grader', 'regard'],
#  'aisv': ['avis', 'visa', 'siva'],
#  'beglu': ['bulge', 'bugle'],
#  "'ainoorst": ["oration's", "ontario's"],
#  "'adels": ["leda's", "dale's", "lead's", "deal's"],
#  'dehnorsu': ['enshroud', 'unhorsed'],
#  "'aehmnrs": ["herman's", "arnhem's"],
#  "'amnors": ["moran's", "norma's", "ramon's", "roman's", "manor's"],
#  'aegimnr': ['mangier', 'reaming'],
#  'eghin': ['neigh', 'hinge'],
#  'elosu': ['louse', 'seoul'],
#  'cdeesu': ['deuces', 'seduce'],
#  "'aekls": ["lake's", "leak's", "kale's"],
#  'binru': ['rubin', 'bruin'],
#  "'aailrst": ["lariat's", "altair's"],
#  'efhiisstt': ['fetishist', 'shiftiest'],
#  'aceilsst': ['elastics', 'alcestis', 'scaliest'],
#  'erstw': ['wrest', 'strew'],
#  "'gorsy": ["orgy's", "gyro's"],
#  'orsty': ['story', 'troys', 'tyros'],
#  'cgimmnsu': ['scumming', 'cummings'],
#  'ceps': ['spec', 'pecs'],
#  "'doors": ["rood's", "door's", "odor's"],
#  'cdeit': ['edict', 'cited'],
#  'ainnost': ['anoints', 'nations'],
#  'anno': ['anon', 'nona'],
#  'egilnorw': ['lowering', 'roweling'],
#  'acenrst': ['trances', 'canters', 'recants', 'scanter'],
#  "'einrss": ["siren's", "rinse's", "resin's"],
#  "'ikrss": ["risk's", "kris's"],
#  "'ceopss": ["scope's", "pecos's", "copse's"],
#  'bp': ['pb', 'bp'],
#  'eillrst': ['stiller', 'tillers', 'trellis'],
#  'ddeefn': ['fended', 'defend'],
#  "'adiors": ["radio's", "dario's"],
#  "'girst": ["girt's", "trig's", "grit's"],
#  'acdert': ['crated', 'carted', 'traced'],
#  'btu': ['tub', 'btu', 'but'],
#  'ceorsu': ['crusoe', 'source', 'course'],
#  'ceefprt': ['prefect', 'perfect'],
#  'agiilnrv': ['virginal', 'rivaling'],
#  "'elors": ["lore's", "role's"],
#  'adir': ['raid', 'arid'],
#  'deilmp': ['dimple', 'limped'],
#  "'aceorrst": ["creator's", "reactor's"],
#  'ailottty': ['totality', 'tolyatti'],
#  "'aersw": ["ware's", "wear's"],
#  'acnny': ['nancy', 'canny'],
#  "'aclors": ["coral's", "carol's", "carlo's"],
#  'ddeellw': ['dwelled', 'weddell'],
#  "'ehiknrst": ["rethink's", "thinker's"],
#  'aartt': ['tatar', 'attar'],
#  'ceghinort': ['creighton', 'hectoring'],
#  'adegilns': ['dealings', 'signaled'],
#  'accehst': ['catches', 'cachets'],
#  'nru': ['run', 'urn'],
#  "'elops": ["opel's", "pole's", "lope's"],
#  'aacorsttu': ['autocrats', 'actuators'],
#  "'gnsu": ["gnu's", "gun's"],
#  'psu': ['ups', 'pus', 'sup'],
#  'deis': ['side', 'dies', 'ides'],
#  "'aprsw": ["wrap's", "warp's"],
#  'aimor': ['maori', 'mario', 'moira'],
#  'adehirr': ['harried', 'hardier'],
#  'acerv': ['carve', 'crave'],
#  'cefinors': ['forensic', 'conifers'],
#  'aeklnr': ['lanker', 'rankle'],
#  "'aerrsstt": ["restart's", "starter's"],
#  'aeenrr': ['earner', 'nearer'],
#  'delsu': ['duels', 'slued'],
#  'hlot': ['loth', 'holt'],
#  'ehnorst': ['thrones', 'hornets', 'shorten'],
#  'adehrst': ['trashed', 'hardest', 'hatreds', 'dearths', 'threads'],
#  "'eoprsst": ["poster's", "presto's"],
#  'eow': ['woe', 'owe'],
#  'aceerrst': ['caterers', 'retraces', 'terraces'],
#  'aegrsu': ['augers', 'argues'],
#  'eorrst': ['torres', 'sorter', 'resort', 'roster'],
#  "'ostw": ["tow's", "two's"],
#  'dioprst': ['tripods', 'disport'],
#  'aahnsu': ['shauna', 'nashua'],
#  'gin': ['ing', 'gin'],
#  "'aeinsv": ["nivea's", "evian's"],
#  'deopst': ['depots', 'despot', 'posted'],
#  'abdr': ['drab', 'brad', 'bard'],
#  'denrsu': ['nursed', 'sunder'],
#  'acehms': ['schema', 'sachem'],
#  'eginsst': ['ingests', 'signets'],
#  'eggmrsu': ['muggers', 'smugger'],
#  'adefrt': ['dafter', 'rafted', 'farted'],
#  'ekost': ['tokes', 'stoke'],
#  'abeillrs': ['liberals', 'ballsier', 'brailles'],
#  'adegln': ['glenda', 'dangle', 'angled'],
#  "'egors": ["roeg's", "ogre's", "gore's"],
#  "'imnost": ["minot's", "timon's"],
#  "'ahnss": ["hans's", "nash's"],
#  'belrstu': ['bluster', 'subtler', 'butlers'],
#  'aginnw': ['awning', 'waning'],
#  'eelrsstw': ['wrestles', 'swelters'],
#  "'aeelprsstt": ["saltpetre's", "saltpeter's"],
#  'eoprtu': ['puerto', 'troupe'],
#  'adefint': ['fainted', 'defiant'],
#  'almtuu': ['umlaut', 'mutual'],
#  "'belos": ["lobe's", "bole's"],
#  'ainnot': ['nation', 'anoint'],
#  'adis': ['said', 'dais', 'aids'],
#  "'aeelsst": ["estela's", "teasel's"],
#  'aegiinnortt': ['orientating', 'integration'],
#  'ceiikr': ['ickier', 'rickie'],
#  'cgiknor': ['corking', 'rocking'],
#  'beert': ['beret', 'ebert'],
#  'krtu': ['turk', 'kurt'],
#  'eesw': ['ewes', 'wees'],
#  'aalv': ['alva', 'lava'],
#  'abels': ['basel', 'bales', 'sable'],
#  'eginrw': ['wigner', 'winger'],
#  'ggiilnnt': ['glinting', 'tingling'],
#  'adegiilmns': ['misdealing', 'misleading'],
#  'aessv': ['vases', 'saves'],
#  'deefiis': ['deifies', 'edifies'],
#  "'anors": ["arno's", "aron's", "nora's", "roan's", "oran's"],
#  'dehis': ['shied', 'hides'],
#  'giilntt': ['tilting', 'tlingit', 'titling'],
#  'eivw': ['view', 'wive'],
#  'enorss': ['sensor', 'snores'],
#  'adeerr': ['reared', 'reader', 'reread', 'dearer'],
#  'adelpps': ['slapped', 'dapples'],
#  'beffrsu': ['rebuffs', 'buffers'],
#  'amnoss': ['samson', 'masons'],
#  'aehknr': ['harken', 'hanker'],
#  "'aenprsst": ["pastern's", "napster's"],
#  'aaadmrs': ['madrasa', 'armadas'],
#  'alorv': ['valor', 'orval'],
#  'deeiprss': ['disperse', 'presides'],
#  "'hrstu": ["hurt's", "ruth's"],
#  'acdir': ['dirac', 'acrid'],
#  'acdeiimnot': ['medication', 'decimation'],
#  'agilnst': ['salting', 'lasting', 'slating', 'staling'],
#  "'adeelnrs": ["leander's", "darlene's"],
#  'acelmor': ['carmelo', 'marcelo'],
#  'eefiisstt': ['testifies', 'feistiest'],
#  "'abcels": ["caleb's", "cable's"],
#  'aersttw': ['stewart', 'swatter'],
#  'inps': ['spin', 'snip', 'nips', 'pins'],
#  'acins': ['incas', 'cains'],
#  'elrsu': ['rules', 'lures'],
#  'eilpprs': ['ripples', 'slipper'],
#  "'aceilnors": ["caroline's", "cornelia's"],
#  'deiinoopst': ['deposition', 'positioned'],
#  "'cceilrs": ["circle's", "cleric's"],
#  'aegrrt': ['garret', 'grater', 'garter'],
#  "'adgrs": ["grad's", "drag's"],
#  'imss': ['sims', 'miss', 'isms'],
#  "'eggilns": ["neglig's", "leggin's", "niggle's"],
#  'aelnssu': ['unseals', 'sensual'],
#  'acdnor': ['conrad', 'candor', 'dacron'],
#  'aceelpr': ['percale', 'replace'],
#  'aejn': ['jean', 'jane'],
#  "'eghilnss": ["english's", "shingle's"],
#  'eimrst': ['remits', 'merits', 'mister', 'timers', 'miters'],
#  "'aceenrrst": ["recreant's", "terrance's"],
#  'aeilss': ['aisles', 'lassie'],
#  'deirw': ['wider', 'wired', 'weird'],
#  'dmoo': ['mood', 'doom', 'odom'],
#  "'abehrs": ["brahe's", "haber's", "rehab's"],
#  "'adehrst": ["dearth's", "thread's", "hatred's"],
#  'aegims': ['ageism', 'images'],
#  'bbdemo': ['mobbed', 'bombed'],
#  'aefsst': ['feasts', 'safest'],
#  'elmnos': ['lemons', 'solemn', 'melons'],
#  'bho': ['hbo', 'hob'],
#  'epsst': ['pests', 'steps'],
#  "'amnorss": ["romans's", "ransom's"],
#  "'cdeeirsttu": ["rectitude's", "certitude's"],
#  'aadmrs': ['dramas', 'madras'],
#  'ademr': ['dream', 'armed'],
#  "'inpss": ["snip's", "spin's"],
#  'inptu': ['putin', 'input'],
#  'aeilnrt': ['reliant', 'latiner', 'retinal', 'latrine'],
#  'aer': ['ear', 'are', 'era', 'rae'],
#  "'amsy": ["amy's", "yam's", "may's"],
#  "'aadenns": ["andean's", "deanna's"],
#  'aehmrss': ['mashers', 'marshes'],
#  'cceeghiknr': ['checkering', 'rechecking'],
#  'adeis': ['ideas', 'sadie', 'aides', 'aside'],
#  'istw': ['wits', 'wist'],
#  'aeehinrsst': ['earthiness', 'heartiness'],
#  'anruwy': ['unwary', 'runway'],
#  'aanssu': ['saunas', 'susana', 'nassau'],
#  'adegnr': ['garden', 'gander', 'ranged', 'danger'],
#  'eeprssu': ['perseus', 'peruses'],
#  'gnorw': ['wrong', 'grown'],
#  'eerssv': ['serves', 'severs', 'verses'],
#  'aerstw': ['waters', 'rawest', 'waster'],
#  "'aeginnost": ["antigone's", "negation's"],
#  'dehrs': ['shred', 'sherd', 'herds'],
#  'degilnostu': ['ungodliest', 'longitudes'],
#  'ehorss': ['shores', 'horses'],
#  'aaceinrst': ['sectarian', 'ascertain', 'cartesian'],
#  'hnors': ['shorn', 'horns'],
#  'aceimr': ['mercia', 'marcie', 'crimea'],
#  "'aabhistt": ["habitat's", "tabitha's"],
#  "'aehmrsst": ["hamster's", "amherst's"],
#  'achnst': ['snatch', 'stanch', 'chants'],
#  'ainv': ['vain', 'ivan'],
#  'ginsw': ['wings', 'swing'],
#  "'deinnst": ["dentin's", "indent's"],
#  'adnor': ['adorn', 'drano', 'norad', 'radon', 'ronda'],
#  'ceirs': ['cries', 'rices'],
#  'ehlls': ['hells', 'shell'],
#  'adeil': ['ailed', 'delia', 'ideal'],
#  'aemt': ['mate', 'meat', 'tame', 'team'],
#  'aemstt': ['mattes', 'tamest'],
#  'belsstu': ['bustles', 'sublets'],
#  'eeilmnost': ['limestone', 'milestone'],
#  'agrsu': ['sugar', 'argus'],
#  "'adeems": ["meade's", "medea's", "edema's"],
#  'aajr': ['raja', 'ajar'],
#  'adeelprs': ['pleaders', 'relapsed'],
#  "'ailorssty": ["royalist's", "solitary's"],
#  "'aamrsu": ["maura's", "amaru's"],
#  'abdeerst': ['breasted', 'debaters'],
#  "'ioqstu": ["quoit's", "quito's"],
#  'adew': ['wade', 'awed'],
#  'aerr': ['rare', 'rear'],
#  "'amnsy": ["myna's", "many's"],
#  'aefgiln': ['leafing', 'finagle'],
#  'notw': ['town', 'wont'],
#  'acenors': ['corneas', 'coarsen'],
#  'eehirrs': ['sherrie', 'rehires'],
#  "'derrsy": ["ryder's", "dryer's"],
#  'aehlrt': ['halter', 'lather'],
#  'aeiprs': ['praise', 'spirea', 'persia', 'aspire'],
#  "'adirssu": ["radius's", "darius's"],
#  'opt': ['pot', 'opt', 'top'],
#  'aginnpsw': ['spawning', 'wingspan'],
#  'cdeors': ['scored', 'credos', 'decors'],
#  'ikn': ['ink', 'kin'],
#  "'deinnos": ["donnie's", "dionne's"],
#  'aailmn': ['manila', 'malian', 'animal'],
#  'addegln': ['gladden', 'dangled'],
#  'gilmnpu': ['lumping', 'pluming'],
#  'abdir': ['rabid', 'braid', 'baird'],
#  'cdei': ['dice', 'iced'],
#  'aelnrt': ['rental', 'antler', 'learnt'],
#  'deirt': ['tried', 'tired'],
#  "'abdeos": ["abode's", "adobe's"],
#  "'aknst": ["kant's", "tank's"],
#  'adeemnor': ['demeanor', 'enamored'],
#  'aglss': ['glass', 'slags'],
#  "'goops": ["goop's", "pogo's"],
#  'addlnoow': ['download', 'woodland'],
#  "'acehoprs": ["pechora's", "poacher's"],
#  'alprty': ['partly', 'paltry'],
#  'adhs': ['dash', 'shad'],
#  "'cehilnos": ["nichole's", "helicon's"],
#  'aeelrs': ['sealer', 'reales', 'resale'],
#  'eginor': ['region', 'ignore'],
#  'adeisstt': ['distaste', 'staidest'],
#  'aenv': ['evan', 'nave', 'neva', 'vane'],
#  'abbbdel': ['babbled', 'blabbed'],
#  "'aeilnsssst": ["saltiness's", "stainless's"],
#  'ilnost': ['tonsil', 'liston'],
#  'aelmrt': ['armlet', 'martel'],
#  'abbdels': ['slabbed', 'dabbles'],
#  "'acerrst": ["carter's", "tracer's", "crater's"],
#  "'aesy": ["aye's", "yea's"],
#  'ceorst': ['corset', 'escort', 'sector', 'cortes'],
#  'arsty': ['satyr', 'trays', 'artsy', 'stray'],
#  'dim': ['mid', 'dim'],
#  'agims': ['agism', 'sigma'],
#  'aegln': ['glean', 'angle', 'galen', 'angel'],
#  'cdekost': ['dockets', 'stocked'],
#  'abekrs': ['breaks', 'bakers', 'brakes'],
#  'ilos': ['soli', 'silo', 'oils', 'lois', 'soil'],
#  'eginorrst': ['restoring', 'resorting'],
#  'deghilt': ['delight', 'lighted'],
#  'bcistu': ['cubist', 'cubits'],
#  'oort': ['root', 'oort'],
#  'ijno': ['join', 'joni'],
#  'aacellp': ['laplace', 'capella'],
#  'behirrst': ['rebirths', 'birthers'],
#  'cdeinrs': ['rescind', 'discern', 'cinders'],
#  'aehsv': ['haves', 'shave'],
#  'ceeenrrt': ['recenter', 'terrence'],
#  'ehirssv': ['shivers', 'shrives'],
#  'aalmnoy': ['layamon', 'anomaly'],
#  'alnnu': ['luann', 'annul'],
#  "'chiksst": ["shtick's", "kitsch's"],
#  'eilr': ['riel', 'rile', 'lire'],
#  'aeehnrt': ['earthen', 'teheran', 'hearten'],
#  'adeforrtw': ['afterword', 'waterford'],
#  'almpy': ['palmy', 'amply'],
#  'moprs': ['romps', 'proms'],
#  'eeiqrtu': ['requite', 'quieter'],
#  "'acilnsu": ["alcuin's", "lucian's"],
#  'adellnr': ['randell', 'darnell'],
#  'aceiinottx': ['excitation', 'intoxicate'],
#  'adiry': ['dairy', 'diary'],
#  "'aehlmrs": ["mahler's", "harlem's"],
#  'cehos': ['chose', 'echos'],
#  'nosty': ['tyson', 'stony'],
#  'aailntv': ['valiant', 'latvian'],
#  'cehiknt': ['thicken', 'kitchen'],
#  'aceinorst': ['creations', 'reactions'],
#  'imost': ['omits', 'moist'],
#  'ciprs': ['crisp', 'scrip'],
#  'aknst': ['tanks', 'stank'],
#  "'cefhist": ["fichte's", "fetich's"],
#  'adeht': ['death', 'hated'],
#  'aeeiprsstt': ['striptease', 'tapestries'],
#  'adestt': ['tasted', 'stated'],
#  'alpsy': ['plays', 'palsy', 'splay'],
#  'deimmr': ['dimmer', 'rimmed'],
#  'ehs': ['hes', 'she'],
#  'belmorsy': ['somberly', 'sombrely'],
#  "'egos": ["ego's", "geo's"],
#  'abehs': ['sheba', 'hbase'],
#  "'elorsuv": ["louvre's", "velour's", "louver's"],
#  'adisv': ['davis', 'divas'],
#  'abd': ['bad', 'dab'],
#  'aginoprrt': ['parroting', 'prorating'],
#  "'girsst": ["grist's", "grits's"],
#  'ent': ['net', 'ten'],
#  "'aaeimnnrs": ["armenian's", "annmarie's", "marianne's"],
#  'deglno': ['longed', 'golden'],
#  'acginost': ['coatings', 'coasting', 'agnostic'],
#  'adehps': ['phased', 'shaped'],
#  'aestw': ['waste', 'sweat'],
#  'adeflr': ['flared', 'alfred'],
#  'aemst': ['tames', 'mates', 'teams', 'steam', 'meats'],
#  'eefilst': ['liefest', 'lefties'],
#  'aagl': ['alga', 'gala'],
#  'acgillnops': ['scalloping', 'collapsing'],
#  'alms': ['slam', 'lams', 'alms'],
#  "'acmors": ["carom's", "macro's", "marco's"],
#  'aeeglnrs': ['enlarges', 'generals'],
#  'aeeginnrt': ['argentine', 'tangerine'],
#  'aacggilnotu': ['cataloguing', 'coagulating'],
#  'acdeehrtt': ['chattered', 'ratcheted'],
#  'aegilnrt': ['altering', 'relating', 'integral', 'triangle', 'alerting'],
#  'adeoprrt': ['predator', 'parroted', 'teardrop', 'prorated'],
#  'eiknrst': ['kristen', 'tinkers', 'kirsten', 'stinker'],
#  'dsstu': ['studs', 'dusts'],
#  'aor': ['oar', 'ora'],
#  'eeir': ['eire', 'erie'],
#  'aeirrv': ['rivera', 'arrive'],
#  'deiorst': ['steroid', 'sortied', 'storied', 'editors'],
#  "'ahmnsu": ["nahum's", "human's"],
#  "'eghins": ["hinge's", "neigh's"],
#  'aaginrrs': ['arraigns', 'srinagar'],
#  'ceilrs': ['slicer', 'relics'],
#  'beir': ['brie', 'bier'],
#  'aekrsst': ['skaters', 'streaks'],
#  'ceeinrsu': ['sinecure', 'insecure'],
#  'egors': ['ogres', 'gorse', 'gores'],
#  'aeiprst': ['parties', 'traipse', 'pastier', 'pirates'],
#  'deesw': ['weeds', 'sewed', 'swede'],
#  'aegilnps': ['elapsing', 'pleasing'],
#  'adeilotv': ['violated', 'dovetail'],
#  "'aegrsz": ["graze's", "gazer's"],
#  "'aelsz": ["zeal's", "laze's"],
#  'brtu': ['brut', 'burt'],
#  'cefhit': ['fichte', 'fetich'],
#  'aeinpst': ['sapient', 'panties'],
#  ...}

# %%
# %time anagram_map = all_anagram_lists(word_list)

# %%
len(anagram_map)
#print(anagram_map)

# %%
anagram_map = all_anagram_lists(word_list)

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
# Original program already does this

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
# Simple function to return the length of the key
def get_len(key):
    return len(key[0])

def get_sorted(ana_dict):
    # Turns the dictionary to a list of tuples
    anagram_dict_list = list(ana_dict.items())
    # Sorts the list of tuples based on word length
    anagram_dict_list.sort(reverse = True, key = get_len)
    # Turning list back to a dictionary
    sorted_dict = {ele[0] : ele[1]  for ele in anagram_dict_list}
    return sorted_dict

def get_longest(dict):
    # Turns the dictionary to a list of tuples
    anagram_dict_list = list(dict.items())
    # Sorts the list of tuples based on word length
    anagram_dict_list.sort(reverse = True, key = get_len)
    return anagram_dict_list[0][1]

get_longest(anagram_map)
# Out:
# ["permissiveness's", "impressiveness's"]

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
def get_most(dict):
    current_most = []
    # Turns the dictionary to a list of tuples
    anagram_dict_list = list(dict.items())

    # Loops through the list for each element
    for gram in anagram_dict_list:
            # Checks to see if there are more values in the current itteration than the current biggest
            if len(gram[1]) > len(current_most):
                # Sets current biggest to current itteration if current itteration was larger
                current_most = gram[1]
    
    return current_most

get_most(anagram_map)
# Out:
# ['stale', 'stael', 'least', 'teals', 'slate', 'steal', 'tales', 'tesla']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
