# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False
 # True

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 1.29 µs ± 10.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 4.32 µs ± 57 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False


def all_anagram_pairs(word_list):
    word_count = len(word_list)
    i = 0
    pairs = []

    while i != word_count:
        checking = word_list[i]
        for word in word_list:
            if word == checking:
                continue
            elif is_anagram(checking, word):
                pairs.append((checking, word))
        i += 1
    
    pair_count = len(pairs)
        
        
    return pairs

all_anagram_pairs(short_word_list)
# Out:
# [('proudest', 'sprouted'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('pots', 'stop'),
#  ('pots', 'tops'),
#  ('tops', 'stop'),
#  ('tops', 'pots'),
#  ('sprouted', 'proudest')]

# %%
all_anagram_pairs(short_word_list)
# Out:
# [('proudest', 'sprouted'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('pots', 'stop'),
#  ('pots', 'tops'),
#  ('tops', 'stop'),
#  ('tops', 'pots'),
#  ('sprouted', 'proudest')]

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
# pairs = all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    anagrams = {}

    # Loop over the list of words
    for word in word_list:
        # Rearrange the word so that each letter is in alphabetical order 
        sorted_word = ''.join(sorted(word))
        # Check if the resorted word is already a key in the dictionary 
        if not anagrams.get(sorted_word):
            # Create a key with the resorted word if it is not and add the normal unsorted word as a value
            anagrams.update({sorted_word: [1, word]})
        else:
            # Just add the unsorted word as a value to the already existing key
            anagrams[sorted_word].append(word)
            anagrams[sorted_word][0] += 1
    
    # Turn the dictionary into a list of tuples
    anagrams_list = list(anagrams.items())
    length = len(anagrams_list) - 1    
    # Save the list
    store_anagrams_list = anagrams_list
    # Loop through the list for each element in anagrams_list:
    while length != -1:
        # If length of the second value of the tuple is 1 then remove it from the list
        if anagrams_list[length][1][0] == 1:
            store_anagrams_list.remove(anagrams_list[length])
            length -= 1
        else:
            # Clean up the list by removing coutner element
            del store_anagrams_list[length][1][0]
            length -= 1
        
    # Turn the list back into a dictionary        
    true_anagrams = {ele[0] : ele[1]  for ele in store_anagrams_list}
    # Return the dictionary
    return true_anagrams
# Out:
# {'adeinst': ['detains', 'instead', 'stained'],
#  'aeksst': ['stakes', 'skates', 'steaks'],
#  'egrsu': ['urges', 'surge'],
#  'denoprs': ['ponders', 'respond'],
#  'eeiilnrst': ['listerine', 'resilient'],
#  'adeelpr': ['pleader', 'pearled'],
#  'acdeeilnrt': ['interlaced', 'credential'],
#  'elrsy': ['lyres', 'slyer'],
#  "'aefst": ["feat's", "feta's", "fate's"],
#  'ahns': ['nash', 'hans'],
#  'amps': ['amps', 'maps', 'spam'],
#  'eegilnr': ['leering', 'reeling'],
#  'enorss': ['sensor', 'snores'],
#  'bdeinrs': ['binders', 'rebinds'],
#  'aeimnrs': ['remains', 'marines', 'seminar'],
#  "'abils": ["bail's", "bali's"],
#  'deenrs': ['resend', 'denser', 'sender'],
#  'adeinrsst': ['streisand', 'tardiness'],
#  'adens': ['sedan', 'snead', 'sedna', 'danes', 'andes', 'deans'],
#  'estw': ['wets', 'stew', 'west'],
#  "'dinos": ["odin's", "dino's", "dion's"],
#  'aelstx': ['exalts', 'laxest'],
#  "'beors": ["ebro's", "robe's", "boer's", "bore's"],
#  'ceorsst': ['sectors', 'corsets', 'escorts'],
#  'dilos': ['solid', 'idols'],
#  'accgikln': ['clacking', 'cackling'],
#  "'aalsss": ["lassa's", "salsa's", "salas's"],
#  "'gilnos": ["lingo's", "login's"],
#  'aaeehhimprstt': ['amphitheaters', 'amphitheatres'],
#  'cdeeoprru': ['reproduce', 'procedure'],
#  'cdlos': ['scold', 'clods', 'colds'],
#  'dorwy': ['wordy', 'dowry', 'rowdy'],
#  "'ehlorsst": ["hostler's", "holster's"],
#  'ginoprstu': ['sprouting', 'posturing'],
#  "'adens": ["aden's", "dena's", "edna's", "dane's", "dean's"],
#  'aehisstt': ['atheists', 'hastiest'],
#  'abdr': ['drab', 'brad', 'bard'],
#  'ccikloy': ['colicky', 'cockily'],
#  "'cost": ["cot's", "oct's"],
#  'aben': ['bane', 'bean'],
#  'dens': ['dens', 'ends', 'send'],
#  'amp': ['map', 'amp', 'pam'],
#  'ceeprs': ['crepes', 'creeps'],
#  'degloss': ['glossed', 'godless'],
#  'aacinr': ['carina', 'crania'],
#  'giinrs': ['rising', 'siring'],
#  'aeln': ['lane', 'lean', 'neal', 'lena'],
#  'aceln': ['lance', 'clean'],
#  'aemns': ['manes', 'manse', 'means', 'mensa', 'names'],
#  'girt': ['girt', 'grit', 'trig'],
#  'dhos': ['hods', 'shod'],
#  'ain': ['ina', 'ian', 'ani'],
#  'ehirs': ['shire', 'hires', 'heirs', 'sheri'],
#  "'adenrss": ["sander's", "andres's"],
#  'adimnos': ['madison', 'domains'],
#  "'eeirs": ["erie's", "eire's"],
#  'defiiln': ['infidel', 'infield'],
#  'aeklrst': ['talkers', 'stalker'],
#  'aeeilrst': ['earliest', 'ateliers'],
#  'deilps': ['dispel', 'lisped'],
#  'aelstt': ['latest', 'lattes'],
#  'egiimmnrs': ['immersing', 'simmering'],
#  'moors': ['rooms', 'moors'],
#  'dis': ['dis', 'sid', 'ids'],
#  "'aailsv": ["avila's", "avail's"],
#  'ginrtu': ['truing', 'turing'],
#  'eorstt': ['tortes', 'otters'],
#  'acdesu': ['sauced', 'caused'],
#  'abdeo': ['abode', 'adobe'],
#  'aeehrstw': ['wreathes', 'weathers'],
#  'istw': ['wist', 'wits'],
#  'adefrt': ['rafted', 'dafter', 'farted'],
#  'eehrt': ['there', 'ether', 'three'],
#  'mssu': ['sums', 'muss'],
#  'ampr': ['ramp', 'pram'],
#  'ckor': ['kroc', 'cork', 'rock'],
#  'egptu': ['puget', 'getup'],
#  'aefgiln': ['leafing', 'finagle'],
#  'eorsstu': ['ousters', 'sourest'],
#  'beimrst': ['timbres', 'timbers'],
#  'aeeglnrs': ['generals', 'enlarges'],
#  'aelrsv': ['slaver', 'ravels', 'salver'],
#  "'ellssw": ["swell's", "wells's"],
#  'acemrs': ['scream', 'creams'],
#  "'aehls": ["hale's", "leah's"],
#  'air': ['air', 'ira'],
#  'gins': ['sing', 'gins', 'sign'],
#  'ersttu': ['truest', 'utters'],
#  'abmru': ['rumba', 'burma'],
#  'cemprstu': ['spectrum', 'crumpets'],
#  'aeghnopt': ['heptagon', 'pathogen'],
#  'eist': ['site', 'ties'],
#  'aeps': ['apse', 'apes', 'peas'],
#  'abelnu': ['nebula', 'unable'],
#  'defloor': ['flooder', 'floored'],
#  'deinstt': ['dentist', 'stinted'],
#  'deeeiprstx': ['preexisted', 'expediters'],
#  'deeinrst': ['inserted', 'resident', 'dniester', 'trendies', 'nerdiest'],
#  'aceilst': ['laciest', 'elastic'],
#  'opsst': ['posts', 'spots', 'stops'],
#  "'eilmss": ["miles's", "slime's", "selim's", "smile's"],
#  'adeeirst': ['steadier', 'readiest'],
#  "'ahlsu": ["hula's", "haul's"],
#  'afrst': ['frats', 'rafts', 'farts'],
#  "'ceinsst": ["incest's", "insect's"],
#  "'cdeeirsttu": ["rectitude's", "certitude's"],
#  'eginoprs': ['reposing', 'spongier'],
#  "'giprs": ["grip's", "prig's"],
#  'einops': ['opines', 'ponies'],
#  'ceefprst': ['prefects', 'perfects'],
#  'aillortt': ['littoral', 'tortilla'],
#  'cilry': ['cyril', 'lyric'],
#  'eimnstu': ['minuets', 'minutes'],
#  'hrsttu': ['truths', 'thrust'],
#  'eorsst': ['sorest', 'stores'],
#  'adelor': ['laredo', 'ordeal', 'reload', 'loader'],
#  "'aflos": ["olaf's", "loaf's", "foal's"],
#  'aclopu': ['copula', 'cupola'],
#  'ajnos': ['jonas', 'jason', 'sonja'],
#  "'aaikss": ["sakai's", "kasai's"],
#  "'aelnors": ["lorena's", "elanor's", "lenora's", "elnora's", "loaner's"],
#  'acdegiimnt': ['medicating', 'decimating'],
#  'adeeilmnrst': ['derailments', 'streamlined'],
#  'bdelu': ['lubed', 'blued'],
#  'egginr': ['nigger', 'ginger'],
#  'cdinostu': ['discount', 'conduits'],
#  'deep': ['peed', 'deep'],
#  'acdehnstu': ['unscathed', 'staunched'],
#  'adert': ['tread', 'trade', 'tared', 'rated'],
#  'deinor': ['ironed', 'indore'],
#  'abeltt': ['battle', 'tablet'],
#  'ikln': ['kiln', 'link'],
#  'beelr': ['rebel', 'berle'],
#  'nopsstu': ['unstops', 'sunspot'],
#  'aepst': ['septa', 'spate', 'pates', 'paste', 'tapes'],
#  'ahlos': ['shoal', 'halos'],
#  'acgir': ['cigar', 'craig'],
#  'acdeeimst': ['decimates', 'medicates'],
#  "'enos": ["eon's", "one's", "noe's", "neo's"],
#  "'emost": ["mote's", "tome's", "moet's"],
#  'aeinnrstt': ['intranets', 'transient'],
#  "'loost": ["tool's", "loot's"],
#  'deiinost': ['sedition', 'editions'],
#  'aekqsu': ['squeak', 'quakes'],
#  'aaddms': ['saddam', 'addams'],
#  'anors': ['sonar', 'roans', 'arson'],
#  'eilnsst': ['silents', 'enlists', 'tinsels', 'listens'],
#  'enost': ['notes', 'tones', 'onset', 'stone', 'seton'],
#  'bilmo': ['mobil', 'limbo'],
#  'ablm': ['balm', 'lamb'],
#  'beors': ['boers', 'sober', 'bores', 'robes'],
#  'eopss': ['posse', 'pesos', 'poses'],
#  'defsu': ['fused', 'feuds'],
#  'adeerst': ['dearest', 'tasered', 'sedater'],
#  'akos': ['oaks', 'soak'],
#  "'aegorst": ["garote's", "ortega's", "tagore's"],
#  'deilms': ['smiled', 'misled'],
#  'deo': ['ode', 'doe'],
#  'aelssv': ['slaves', 'salves'],
#  'agginp': ['gaping', 'paging'],
#  "'eerss": ["erse's", "seer's"],
#  "'abels": ["abel's", "bela's", "bale's", "elba's"],
#  'aahnns': ['anshan', 'shanna'],
#  'emprs': ['perms', 'sperm'],
#  "'acrsy": ["cary's", "cray's"],
#  'ehnost': ['honest', 'heston'],
#  'ciilost': ['colitis', 'solicit'],
#  'dino': ['dion', 'dino', 'odin'],
#  "'aegimrs": ["margie's", "mirage's"],
#  "'eehnorsw": ["nowhere's", "erewhon's"],
#  'aegs': ['ages', 'sega', 'sage'],
#  'aeekorstv': ['takeovers', 'overtakes'],
#  'eegiinnnrtv': ['reinventing', 'intervening'],
#  'los': ['los', 'sol'],
#  'eilsv': ['evils', 'elvis', 'veils', 'lives'],
#  "'afrst": ["fart's", "frat's", "raft's"],
#  'eeilrv': ['relive', 'revile', 'eviler'],
#  'delmos': ['models', 'seldom'],
#  "'denos": ["deon's", "node's"],
#  "'cdeiorrst": ["director's", "creditor's"],
#  'aey': ['yea', 'aye'],
#  'deeprtu': ['erupted', 'reputed'],
#  'acelmor': ['carmelo', 'marcelo'],
#  'egimnpt': ['pigment', 'temping'],
#  'aehmnr': ['arnhem', 'herman'],
#  'elnos': ['noels', 'olsen'],
#  'beelrt': ['elbert', 'treble'],
#  'adelnr': ['lenard', 'lander'],
#  'adry': ['yard', 'dray'],
#  "'agnorss": ["sargon's", "sarong's"],
#  'ehorsv': ['hovers', 'shrove'],
#  "'eehrsst": ["hester's", "esther's"],
#  'arstw': ['straw', 'warts'],
#  'aehrst': ['haters', 'hearts', 'hearst', 'earths'],
#  "'illst": ["lilt's", "till's"],
#  'airsst': ['sitars', 'stairs'],
#  "'einsst": ["stein's", "inset's", "stine's"],
#  'eopssu': ['spouse', 'opuses'],
#  "'elrsu": ["lure's", "rule's"],
#  'adehlnst': ['shetland', 'stendhal'],
#  'estv': ['vest', 'vets'],
#  "'eiorss": ["osier's", "rosie's"],
#  'adeelry': ['layered', 'relayed'],
#  'agilnps': ['lapsing', 'palings', 'sapling'],
#  'aehmrss': ['marshes', 'mashers'],
#  'aeerrssu': ['reassure', 'erasures'],
#  'aelmpr': ['palmer', 'ampler', 'marple'],
#  "'beglsu": ["bugle's", "bulge's"],
#  'cost': ['cost', 'cots', 'scot'],
#  'adrw': ['draw', 'ward'],
#  'abdeorr': ['broader', 'boarder'],
#  'amors': ['roams', 'ramos'],
#  'celnoy': ['ceylon', 'conley'],
#  'acinotu': ['auction', 'caution'],
#  'deins': ['dines', 'snide', 'denis'],
#  'acilsv': ['slavic', 'vlasic', 'cavils'],
#  'adegginnr': ['gardening', 'deranging'],
#  'aemnt': ['manet', 'meant'],
#  'abdekr': ['braked', 'barked', 'debark'],
#  'deeerrsv': ['reversed', 'reserved'],
#  'ceeprst': ['respect', 'specter', 'scepter'],
#  'cimnors': ['microns', 'crimson'],
#  "'aegginors": ["georgina's", "georgian's"],
#  'eehrsw': ['hewers', 'wheres'],
#  'bdeknu': ['bunked', 'debunk'],
#  'aeksw': ['wesak', 'wakes', 'askew'],
#  "'aadins": ["naiad's", "diana's", "nadia's"],
#  'aekst': ['steak', 'keats', 'takes', 'skate', 'stake', 'teaks'],
#  'cikls': ['licks', 'slick'],
#  'aegimns': ['enigmas', 'gamines', 'seaming'],
#  "'beorsst": ["osbert's", "strobe's", "sorbet's"],
#  'allosw': ['allows', 'sallow'],
#  'adeinr': ['andrei', 'rained'],
#  'adeels': ['sealed', 'leased'],
#  'einprs': ['sniper', 'ripens'],
#  'aelv': ['vela', 'elva', 'veal', 'vale'],
#  'aeelprstt': ['saltpeter', 'saltpetre'],
#  'eeinrstu': ['reunites', 'retinues'],
#  'deeeinnrtv': ['intervened', 'reinvented'],
#  'ceirrssu': ['scurries', 'cruisers'],
#  'amrst': ['marts', 'smart', 'trams'],
#  'art': ['tar', 'rat', 'art'],
#  "'noopss": ["snoop's", "spoon's"],
#  'aceilr': ['lacier', 'claire'],
#  "'ceeprs": ["crepe's", "creep's"],
#  'acginrv': ['craving', 'carving'],
#  'deiopst': ['topside', 'dopiest', 'posited', 'deposit'],
#  "'eelnors": ["lenore's", "lorene's"],
#  'eflt': ['left', 'felt'],
#  'abdelm': ['lambed', 'bedlam', 'ambled', 'blamed'],
#  'adlny': ['lynda', 'dylan'],
#  "'aghss": ["shag's", "gash's"],
#  'aelno': ['alone', 'leona', 'oneal'],
#  "'acellrs": ["cellar's", "caller's", "recall's"],
#  "'deinorsssw": ["wordiness's", "rowdiness's"],
#  'ist': ['sit', 'its'],
#  "'ahkns": ["hank's", "ankh's", "khan's"],
#  'ainrst': ['strain', 'trains'],
#  'eikl': ['kiel', 'like'],
#  'aintt': ['titan', 'taint'],
#  'deflnoruw': ['underflow', 'wonderful'],
#  "'aessst": ["tessa's", "asset's"],
#  "'aegrsz": ["gazer's", "graze's"],
#  "'einrss": ["rinse's", "resin's", "siren's"],
#  'accersu': ['accrues', 'accuser'],
#  'aestt': ['state', 'teats', 'taste'],
#  'egt': ['gte', 'get'],
#  "'alrsu": ["raul's", "ural's"],
#  'acdeirr': ['carried', 'acrider'],
#  'iklls': ['kills', 'skill'],
#  'ilst': ['silt', 'list', 'slit'],
#  'efhiinrs': ['refinish', 'finisher'],
#  "'hosw": ["who's", "how's"],
#  "'aghilmorst": ["logarithm's", "algorithm's"],
#  'aeimnoprttu': ['importunate', 'permutation'],
#  'aenprstt': ['transept', 'patterns'],
#  'ader': ['read', 'dare', 'dear'],
#  'deimr': ['rimed', 'mired', 'dimer'],
#  'efir': ['fire', 'rife'],
#  'acen': ['cane', 'acne'],
#  'aiv': ['iva', 'via'],
#  'deilp': ['piled', 'plied'],
#  'acehss': ['chases', 'cashes'],
#  "'cehors": ["ochre's", "roche's", "ocher's", "chore's"],
#  'aajr': ['raja', 'ajar'],
#  'bdenorsu': ['rebounds', 'suborned', 'bounders'],
#  'acinoss': ['caisson', 'casinos', 'cassino'],
#  'illt': ['till', 'lilt'],
#  'abcdeirs': ['carbides', 'ascribed'],
#  'deeerv': ['veered', 'reeved'],
#  "'eelmrs": ["elmer's", "merle's"],
#  'adesz': ['dazes', 'adzes'],
#  'alsw': ['awls', 'slaw', 'laws'],
#  "'aesy": ["yea's", "aye's"],
#  'aceh': ['ache', 'each'],
#  'adddeemn': ['maddened', 'demanded'],
#  'es': ['se', 'es'],
#  'doors': ['odors', 'roods', 'doors'],
#  'adeoprrt': ['parroted', 'teardrop', 'predator', 'prorated'],
#  'densttu': ['stunted', 'student'],
#  'aaimnrt': ['martina', 'martian'],
#  'ainsty': ['sanity', 'satiny'],
#  'aeinprt': ['pertain', 'painter', 'repaint'],
#  "'belsu": ["lube's", "blue's"],
#  'cefhit': ['fichte', 'fetich'],
#  'ciiknpst': ['stickpin', 'nitpicks'],
#  'nosty': ['stony', 'tyson'],
#  "'aprst": ["part's", "trap's", "tarp's"],
#  "'achmrs": ["charm's", "march's"],
#  "'ehkoorssuw": ["workhouse's", "housework's"],
#  'aaadmr': ['ramada', 'armada'],
#  'mnoru': ['mourn', 'munro'],
#  'bins': ['bins', 'nibs'],
#  'adlu': ['laud', 'dual'],
#  'iprst': ['trips', 'strip'],
#  'cefiklr': ['fickler', 'flicker'],
#  'giorv': ['vigor', 'virgo'],
#  'eefginr': ['reefing', 'freeing'],
#  "'acelrs": ["clear's", "clare's"],
#  'aacnz': ['nazca', 'anzac'],
#  'cenorstu': ['counters', 'construe', 'recounts', 'trounces'],
#  'ghu': ['ugh', 'hug'],
#  'abdelrw': ['warbled', 'brawled'],
#  'aeijm': ['jaime', 'mejia', 'jamie'],
#  'aeilmsttu': ['stimulate', 'mutilates'],
#  "'giorsv": ["vigor's", "virgo's"],
#  'ainnot': ['anoint', 'nation'],
#  "'acenrst": ["cretan's", "trance's", "nectar's", "canter's"],
#  'orstt': ['torts', 'trots'],
#  'amorsy': ['morays', 'mayors'],
#  'behirrt': ['birther', 'rebirth'],
#  'elpprsu': ['purples', 'suppler'],
#  'ailms': ['islam', 'mails'],
#  "'demos": ["dome's", "mode's", "demo's"],
#  'deghilt': ['delight', 'lighted'],
#  'aceeinrsst': ['ancestries', 'resistance'],
#  "'imrs": ["rim's", "mir's"],
#  'aderstw': ['steward', 'strawed'],
#  'iiksw': ['wikis', 'kiwis'],
#  'degilnostu': ['longitudes', 'ungodliest'],
#  "'aeprs": ["earp's", "rape's", "pear's"],
#  'lprsu': ['slurp', 'purls'],
#  'aeegimnprt': ['permeating', 'impregnate'],
#  'ennot': ['tenon', 'tonne'],
#  'aceil': ['alice', 'celia'],
#  "'aacellps": ["capella's", "laplace's"],
#  "'acgirs": ["craig's", "cigar's"],
#  'ddeefil': ['fielded', 'defiled'],
#  "'bdemoors": ["bedroom's", "boredom's"],
#  'aegiln': ['linage', 'genial'],
#  'apsty': ['pasty', 'patsy'],
#  'moprs': ['proms', 'romps'],
#  'aelprsy': ['parsley', 'replays', 'parleys', 'players', 'sparely'],
#  "'nrsu": ["urn's", "run's"],
#  'acegilnns': ['cleansing', 'cleanings'],
#  'eekl': ['keel', 'leek', 'klee'],
#  'einru': ['inure', 'urine'],
#  "'aegprs": ["grape's", "pager's"],
#  "'beffrsu": ["rebuff's", "buffer's"],
#  "'adenrs": ["nader's", "andre's", "arden's", "daren's"],
#  'eestw': ['weest', 'sweet'],
#  "'cosst": ["cost's", "scot's"],
#  'adeimns': ['medians', 'maidens'],
#  "'ailss": ["sail's", "lisa's"],
#  'aerrsstt': ['starters', 'restarts'],
#  "'adils": ["dial's", "dali's"],
#  'adeinnoott': ['detonation', 'denotation'],
#  "'bnossu": ["bosun's", "bonus's", "bo'suns"],
#  'einrv': ['ervin', 'riven'],
#  'aenrs': ['earns', 'nears', 'snare', 'saner'],
#  'eeelsv': ['sleeve', 'levees'],
#  'acelpr': ['carpel', 'parcel', 'placer'],
#  'abeirs': ['braise', 'serbia', 'rabies'],
#  'acnors': ['carson', 'acorns'],
#  'efirs': ['fries', 'fires'],
#  "'aehrst": ["hater's", "earth's", "heart's", "harte's"],
#  'demnotu': ['demount', 'mounted'],
#  "'adnors": ["radon's", "norad's", "drano's", "ronda's"],
#  'adimst': ['amidst', 'admits'],
#  'eelsty': ['steely', 'sleety'],
#  'einsx': ['nexis', 'nixes'],
#  'emno': ['omen', 'nome'],
#  'gilnoos': ['loosing', 'soloing'],
#  'aacelmn': ['manacle', 'alcmena'],
#  'efirr': ['rifer', 'frier'],
#  'dmoos': ['moods', 'sodom', 'dooms'],
#  'adelno': ['loaned', 'delano'],
#  'adeeginnrs': ['grenadines', 'serenading'],
#  "'aelns": ["lane's", "lean's", "neal's", "lena's"],
#  "'cefhis": ["chief's", "fiche's"],
#  "'eiknrstt": ["knitter's", "trinket's"],
#  'aehprss': ['seraphs', 'phrases'],
#  'abdors': ['boards', 'broads'],
#  'adeprs': ['parsed', 'spread', 'spared', 'padres', 'rasped', 'drapes'],
#  'bin': ['bin', 'nib'],
#  "'flosw": ["wolf's", "fowl's", "flow's"],
#  "'cgiinnoost": ["cognition's", "incognito's"],
#  'anrt': ['tran', 'rant'],
#  'egilnorw': ['roweling', 'lowering'],
#  'aest': ['eats', 'sate', 'east', 'seat', 'teas'],
#  'addeeprt': ['predated', 'departed'],
#  'klooostu': ['outlooks', 'lookouts'],
#  'aegimrt': ['ragtime', 'maigret', 'migrate'],
#  'adelms': ['damsel', 'medals'],
#  'abdelst': ['baldest', 'blasted', 'stabled'],
#  'acceemnorsttu': ['accoutrements', 'accouterments'],
#  'got': ['got', 'tog'],
#  'aceelnv': ['valence', 'enclave'],
#  'amnors': ['ransom', 'romans', 'manors'],
#  'ehlorsst': ['holsters', 'hostlers'],
#  'most': ['most', 'toms'],
#  'aegilnrs': ['slangier', 'salinger'],
#  'adiv': ['avid', 'diva'],
#  "'bhorst": ["broth's", "throb's"],
#  'eimntu': ['minute', 'minuet'],
#  "'hlosst": ["holst's", "sloth's"],
#  "'doors": ["door's", "rood's", "odor's"],
#  'ceilnorsu': ['inclosure', 'cornelius'],
#  'bdeinr': ['rebind', 'binder', 'inbred'],
#  'cirstu': ['curtis', 'rustic', 'citrus'],
#  "'eegrss": ["segre's", "serge's"],
#  'aceginrrt': ['retracing', 'cratering', 'terracing'],
#  'aber': ['bare', 'reba', 'bear'],
#  'aegl': ['gale', 'gael'],
#  'rssttu': ['trusts', 'struts'],
#  "'aalmnsu": ["alumna's", "manual's"],
#  'deilst': ['idlest', 'silted', 'listed', 'tildes'],
#  'acenrt': ['cretan', 'recant', 'canter', 'nectar', 'trance'],
#  'ccorsu': ['crocus', 'occurs', 'succor'],
#  'aahnsu': ['shauna', 'nashua'],
#  'delw': ['weld', 'lewd'],
#  "'adegnrs": ["gander's", "danger's", "garden's"],
#  'bdeist': ['bidets', 'debits'],
#  'eilnst': ['listen', 'silent', 'inlets', 'tinsel', 'enlist'],
#  "'aegnos": ["onega's", "genoa's"],
#  'deeinrsst': ['residents', 'tiredness', 'dissenter'],
#  'agimnrst': ['smarting', 'migrants'],
#  'deglo': ['lodge', 'ogled'],
#  'einorssu': ['neurosis', 'resinous'],
#  "'aaeinoprrst": ["praetorian's", "reparation's"],
#  "'aeglnrs": ["angler's", "erlang's"],
#  'acehkls': ['shackle', 'hackles'],
#  'adeefr': ['deafer', 'feared'],
#  'aeiprsu': ['piraeus', 'upraise'],
#  'bdegiint': ['betiding', 'debiting'],
#  'adeehlrt': ['haltered', 'lathered'],
#  'adefil': ['failed', 'afield'],
#  'eegginnr': ['greening', 'reneging'],
#  'aekrsty': ['starkey', 'streaky'],
#  'ailn': ['nail', 'lina', 'lain'],
#  'ceinst': ['incest', 'insect', 'nicest'],
#  'aderrw': ['warder', 'drawer', 'redraw', 'warred', 'reward'],
#  "'bps": ["bp's", "pb's"],
#  'aelmnt': ['mantel', 'lament', 'mantle', 'mental'],
#  "'aaegstwy": ["getaway's", "gateway's"],
#  'aeinpst': ['panties', 'sapient'],
#  "'eersst": ["steer's", "reset's", "ester's"],
#  'eilmpst': ['limpets', 'limpest'],
#  'deerrss': ['dresser', 'redress'],
#  'eegilnrv': ['reveling', 'levering'],
#  'ho': ['oh', 'ho'],
#  'eilppst': ['tipples', 'stipple'],
#  'ginopr': ['roping', 'poring'],
#  "'aissv": ["avis's", "visa's", "siva's"],
#  "'ehorss": ["horse's", "shore's"],
#  "'eipprst": ["tipper's", "trippe's"],
#  'eiprst': ['stripe', 'sprite', 'ripest', 'priest'],
#  'aeinrst': ['retains', 'nastier', 'retinas'],
#  'eepsw': ['sweep', 'weeps'],
#  "'eimst": ["item's", "time's", "mite's"],
#  'ahsw': ['shaw', 'wash', 'haws'],
#  'adelors': ['loaders', 'ordeals', 'reloads'],
#  'npsu': ['puns', 'spun'],
#  'adeelrs': ['dealers', 'leaders'],
#  'enorst': ['tenors', 'sterno', 'nestor', 'tensor', 'stoner'],
#  'deelmor': ['demerol', 'remodel'],
#  'aeltx': ['exalt', 'latex'],
#  'eoqstu': ['quotes', 'toques'],
#  'deeforst': ['fostered', 'forested', 'deforest'],
#  'cdeersu': ['rescued', 'seducer', 'reduces', 'secured'],
#  'aiprs': ['parsi', 'pairs', 'paris'],
#  "'acrs": ["rca's", "arc's", "car's"],
#  'adeelrt': ['related', 'treadle', 'altered', 'alerted'],
#  'agilnst': ['salting', 'lasting', 'slating', 'staling'],
#  'oorst': ['roots', 'roost', 'torso'],
#  'eopr': ['rope', 'pore'],
#  'aginpprst': ['trappings', 'strapping'],
#  'cdeenor': ['encored', 'encoder'],
#  'eginntt': ['tenting', 'netting'],
#  'delow': ['lowed', 'dowel'],
#  'enst': ['tens', 'sent', 'nest', 'nets'],
#  'aeginrs': ['searing', 'regains', 'erasing'],
#  'einrt': ['inter', 'niter', 'inert'],
#  'eemrst': ['meters', 'merest'],
#  'eeersv': ['reeves', 'severe'],
#  'aeeegnrst': ['teenagers', 'generates'],
#  'ceeiprsst': ['tricepses', 'precisest'],
#  'amnor': ['moran', 'roman', 'norma', 'manor', 'ramon'],
#  'aeelrst': ['realest', 'relates'],
#  'ahmnopt': ['hampton', 'phantom'],
#  "'adeils": ["delia's", "ideal's"],
#  'dgiilns': ['sidling', 'sliding'],
#  "'aacnsz": ["nazca's", "anzac's"],
#  'adekr': ['drake', 'raked'],
#  'ddeeir': ['deidre', 'deride'],
#  'adeeinprt': ['pertained', 'repainted'],
#  'adderw': ['edward', 'warded'],
#  "'eehprss": ["herpes's", "sphere's"],
#  'abekrs': ['bakers', 'brakes', 'breaks'],
#  'deeilnst': ['enlisted', 'listened', 'tinseled'],
#  'deefinr': ['refined', 'definer'],
#  "'belnos": ["noble's", "nobel's"],
#  'aeinrrst': ['retrains', 'strainer', 'restrain', 'trainers', 'terrains'],
#  'ahkns': ['shank', 'khans', 'hanks', 'ankhs'],
#  "'deirsv": ["verdi's", "diver's", "drive's"],
#  "'cilrsy": ["lyric's", "cyril's"],
#  'ceopss': ['scopes', 'copses'],
#  'aelrt': ['alert', 'later', 'alter'],
#  "'oosst": ["soto's", "soot's"],
#  "'adeoprrst": ["predator's", "teardrop's"],
#  'defgiiln': ['defiling', 'fielding'],
#  'deiorst': ['storied', 'editors', 'sortied', 'steroid'],
#  "'ckors": ["rock's", "kroc's", "cork's"],
#  "'eillnst": ["lentil's", "lintel's"],
#  'adeeenrtv': ['venerated', 'enervated'],
#  'acdeln': ['candle', 'lanced'],
#  'adeilotv': ['violated', 'dovetail'],
#  'deeiprs': ['perseid', 'preside'],
#  'aeilmrs': ['mailers', 'realism'],
#  'ghlosu': ['ghouls', 'slough'],
#  'aaadmrs': ['madrasa', 'armadas'],
#  'deelnrs': ['slender', 'lenders'],
#  "'achnos": ["nacho's", "cohan's"],
#  'emnoor': ['monroe', 'moreno'],
#  'bnsu': ['nubs', 'snub', 'buns'],
#  'deorv': ['dover', 'roved', 'drove'],
#  'ddeilnsw': ['dwindles', 'swindled'],
#  'adelst': ['staled', 'salted', 'deltas', 'slated', 'lasted'],
#  'bdeeggrsu': ['begrudges', 'debuggers'],
#  'agsw': ['wags', 'swag'],
#  'cdeiprst': ['predicts', 'scripted'],
#  'aghinssw': ['washings', 'swashing'],
#  "'aells": ["ella's", "lela's"],
#  'eimrt': ['remit', 'miter', 'merit', 'timer'],
#  'ceenrs': ['screen', 'censer'],
#  'eelnvy': ['evelyn', 'evenly'],
#  'adel': ['lade', 'leda', 'lead', 'dale', 'deal'],
#  'acdertu': ['traduce', 'decatur'],
#  'aadmrs': ['dramas', 'madras'],
#  'eeimnss': ['siemens', 'nemesis'],
#  "'cceilrs": ["cleric's", "circle's"],
#  'acginost': ['agnostic', 'coasting', 'coatings'],
#  'aaelnn': ['leanna', 'anneal'],
#  'affnors': ['sarnoff', 'saffron'],
#  'aeirvw': ['wavier', 'waiver'],
#  'mpsu': ['umps', 'sump'],
#  'adginrt': ['darting', 'trading'],
#  'adeerrst': ['retreads', 'serrated', 'arrested'],
#  'eginrsw': ['wingers', 'swinger'],
#  "'befirs": ["brief's", "fiber's"],
#  'adeinrtt': ['nitrated', 'andretti'],
#  'deeginrs': ['redesign', 'resigned', 'designer'],
#  "'cirsstu": ["citrus's", "curtis's", "rustic's"],
#  "'aehss": ["ashe's", "shea's"],
#  'aelntt': ['talent', 'latent'],
#  "'adinrs": ["drain's", "indra's", "nadir's", "randi's", "darin's"],
#  'agiinrs': ['raising', 'airings', 'arising'],
#  'egnor': ['goner', 'goren', 'negro'],
#  'aeegilnnt': ['eglantine', 'inelegant'],
#  'denorw': ['downer', 'wonder'],
#  'ceelorst': ['electors', 'selector'],
#  'lop': ['lop', 'pol'],
#  'egiint': ['ignite', 'tieing'],
#  'egilnrst': ['sterling', 'ringlets'],
#  'aaceinrsst': ['ascertains', 'sectarians'],
#  'aaenpst': ['peasant', 'anapest'],
#  'aceprs': ['scrape', 'capers', 'crapes', 'parsec', 'recaps'],
#  'eehprs': ['sphere', 'herpes'],
#  'aelnpt': ['planet', 'platen'],
#  "'anst": ["nat's", "ant's", "tan's"],
#  'ghilopstt': ['spotlight', 'stoplight'],
#  'aegrs': ['rages', 'gears', 'sager'],
#  'ceno': ['once', 'cone'],
#  'eggilns': ['negligs', 'leggins', 'niggles'],
#  "'adefirs": ["frieda's", "freida's"],
#  'emrsu': ['remus', 'serum'],
#  'adeilt': ['detail', 'tailed', 'dilate'],
#  'acdeenrt': ['recanted', 'cantered', 'decanter'],
#  "'acdelrs": ["calder's", "cradle's"],
#  'eefhrrs': ['fresher', 'refresh'],
#  'eflu': ['fuel', 'flue'],
#  'hims': ['hims', 'shim'],
#  'aceinnst': ['canniest', 'ancients', 'instance'],
#  'emors': ['morse', 'mores', 'romes'],
#  'deoprst': ['sported', 'deports'],
#  'elrstu': ['result', 'lustre', 'luster', 'rustle', 'ulster'],
#  'dggilno': ['golding', 'lodging'],
#  'acelns': ['cleans', 'lances'],
#  'beglu': ['bugle', 'bulge'],
#  'abcs': ['scab', 'cabs'],
#  'eisstx': ['exists', 'sexist'],
#  'deissu': ['disuse', 'issued'],
#  'cdeinostu': ['seduction', 'suctioned'],
#  'ilos': ['oils', 'silo', 'soli', 'lois', 'soil'],
#  'deiopsst': ['deposits', 'topsides'],
#  'aegillps': ['pillages', 'spillage'],
#  "'efils": ["leif's", "life's", "file's"],
#  "'aeeinnorstv": ["veneration's", "enervation's"],
#  'aeginnr': ['grannie', 'earning', 'nearing'],
#  'eillvy': ['vilely', 'evilly', 'lively'],
#  'eers': ['seer', 'erse', 'sere'],
#  'beirsu': ['rubies', 'busier', 'bruise', 'buries'],
#  'eeiimprssv': ['permissive', 'impressive'],
#  'aeilrrt': ['retrial', 'trailer'],
#  'addelsw': ['swaddle', 'waddles', 'dawdles'],
#  "'cenorstu": ["counter's", "recount's"],
#  'aestx': ['texas', 'taxes'],
#  'cdeorsu': ['coursed', 'sourced', 'scoured'],
#  'aflot': ['float', 'aloft'],
#  "'blosw": ["bowl's", "blow's"],
#  'gilnpsu': ['plugins', 'pulsing'],
#  'ceehrst': ['etchers', 'chester', 'retches'],
#  'blost': ['blots', 'bolts'],
#  "'eimrs": ["emir's", "meir's", "mire's", "rime's"],
#  'begins': ['begins', 'binges', 'beings'],
#  "'ailms": ["mail's", "lima's", "mali's"],
#  "'aceehrrss": ["research's", "searcher's"],
#  'behilprsu': ['publisher', 'republish'],
#  'ilno': ['loin', 'olin', 'lion'],
#  'enorrstuv': ['overturns', 'turnovers'],
#  'deeeloprv': ['redevelop', 'developer'],
#  'dehissw': ['swedish', 'swished'],
#  'adekst': ['staked', 'skated', 'tasked'],
#  'ginrs': ['grins', 'rings'],
#  "'acilnsu": ["lucian's", "alcuin's"],
#  "'aelsx": ["axle's", "alex's"],
#  'adegr': ['grade', 'edgar', 'raged'],
#  "'ginrs": ["ring's", "grin's"],
#  'aeprst': ['tapers', 'prates', 'repast'],
#  'deggru': ['grudge', 'rugged'],
#  'ahs': ['has', 'ash'],
#  'deenru': ['enured', 'endure'],
#  "'eilsst": ["islet's", "stile's"],
#  "'ioqstu": ["quoit's", "quito's"],
#  'bdeortu': ['redoubt', 'obtrude', 'doubter'],
#  'aerrstt': ['restart', 'starter'],
#  'bdeglu': ['bulged', 'bugled'],
#  "'aderst": ["tread's", "trade's"],
#  'aceorrst': ['reactors', 'creators'],
#  'ilnos': ['loins', 'lions'],
#  'dehors': ['shored', 'rhodes', 'horsed', 'hordes'],
#  'cehinopst': ['phonetics', 'ctesiphon'],
#  "'ainsstu": ["unitas's", "austin's"],
#  "'imst": ["tim's", "mit's"],
#  "'aekrsst": ["skater's", "streak's"],
#  'aehls': ['hales', 'leash', 'shale', 'sahel', 'heals'],
#  'eersv': ['sever', 'verse', 'veers', 'serve'],
#  'abdees': ['seabed', 'debase'],
#  'aeeeprrt': ['repeater', 'repartee'],
#  'aelorsvy': ['layovers', 'overlays'],
#  'aegort': ['garote', 'ortega', 'tagore'],
#  'deensu': ['ensued', 'endues'],
#  'acehrs': ['search', 'arches', 'chaser'],
#  'egginrstu': ['gesturing', 'grungiest'],
#  'eegrt': ['egret', 'greet'],
#  "'abdirs": ["baird's", "braid's"],
#  'dghiins': ['shindig', 'dishing'],
#  "'aaeimnnrs": ["armenian's", "marianne's", "annmarie's"],
#  'cghikno': ['choking', 'hocking'],
#  "'ams": ["ma's", "am's"],
#  'ills': ['ills', 'sill'],
#  'eeilrsv': ['reviles', 'servile', 'relives'],
#  'eilpprs': ['slipper', 'ripples'],
#  'einv': ['vein', 'vine'],
#  'gnrstu': ['grunts', 'strung'],
#  'agls': ['slag', 'gals', 'lags'],
#  'acehrt': ['thrace', 'cather'],
#  'dgos': ['dogs', 'gods'],
#  'aekmrr': ['remark', 'marker', 'kramer'],
#  'aelnv': ['venal', 'navel'],
#  "'celmnoss": ["clemson's", "clemons's"],
#  "'aadenns": ["deanna's", "andean's"],
#  "'behirrst": ["birther's", "rebirth's"],
#  "'aeglns": ["angle's", "galen's", "angel's"],
#  'bdegsu': ['debugs', 'budges'],
#  'cddeei': ['decide', 'deiced'],
#  'abgilnst': ['blasting', 'stabling'],
#  'ago': ['ago', 'goa'],
#  'adeelnrtu': ['unaltered', 'unrelated'],
#  'aeilnorst': ['relations', 'orientals'],
#  'acpr': ['crap', 'carp'],
#  'egilstu': ['ugliest', 'gluiest'],
#  'adeisstt': ['staidest', 'distaste'],
#  'acehrst': ['chaster', 'archest'],
#  'lnoy': ['lyon', 'only'],
#  'psu': ['sup', 'pus', 'ups'],
#  'denot': ['noted', 'toned'],
#  'eilott': ['lottie', 'toilet'],
#  'amost': ['atoms', 'moats', 'tomas'],
#  'deilv': ['devil', 'lived'],
#  'alnnu': ['luann', 'annul'],
#  'adekns': ['kneads', 'snaked'],
#  'apps': ['paps', 'apps'],
#  'cenrsstu': ['curtness', 'encrusts'],
#  "'aderrsw": ["reward's", "drawer's", "warder's"],
#  'aegrsz': ['grazes', 'gazers'],
#  'deopr': ['pored', 'roped', 'pedro'],
#  "'girst": ["grit's", "trig's", "girt's"],
#  'adinor': ['dorian', 'inroad', 'ordain'],
#  "'emrssu": ["remus's", "serum's"],
#  "'amps": ["map's", "amp's", "pam's"],
#  'krtu': ['turk', 'kurt'],
#  'ackls': ['lacks', 'slack', 'calks'],
#  'akprs': ['spark', 'parks'],
#  'eenstv': ['events', 'steven'],
#  'hostu': ['south', 'shout', 'thous'],
#  'abelstt': ['tablets', 'battles'],
#  'aehlt': ['letha', 'lathe'],
#  'aacflrt': ['flatcar', 'fractal'],
#  'aaegrsv': ['ravages', 'savager'],
#  "'acosst": ["coast's", "tosca's", "ascot's"],
#  'deoprt': ['deport', 'ported'],
#  'adeginrrw': ['redrawing', 'rewarding'],
#  'entw': ['newt', 'went'],
#  "'eglrsu": ["gruel's", "luger's"],
#  "'beinrstu": ["tribune's", "turbine's"],
#  'elosvw': ['vowels', 'wolves'],
#  'eimt': ['mite', 'item', 'emit', 'time'],
#  'bstu': ['bust', 'tubs', 'stub', 'buts'],
#  'adenrs': ['snared', 'sander', 'andres'],
#  'cdeiimmnooss': ['commissioned', 'decommission'],
#  'aeginst': ['teasing', 'seating'],
#  'acder': ['arced', 'cadre', 'raced', 'cedar', 'cared'],
#  'aceilmnsu': ['calumnies', 'masculine'],
#  "'aeginrst": ["ingrate's", "granite's"],
#  "'aeimnors": ["romaine's", "moraine's"],
#  'elosu': ['seoul', 'louse'],
#  'eemry': ['emery', 'meyer'],
#  'deeghin': ['neighed', 'heeding'],
#  'adelpps': ['dapples', 'slapped'],
#  'aeilnst': ['saltine', 'entails', 'salient'],
#  'any': ['nay', 'any'],
#  'aadeilstv': ['salivated', 'validates'],
#  'cdeinortu': ['introduce', 'reduction'],
#  'cdeehipr': ['decipher', 'ciphered'],
#  'aegnrst': ['strange', 'sargent', 'garnets'],
#  'enstu': ['unset', 'tunes'],
#  'adehy': ['hayed', 'heady'],
#  'abdsu': ['bauds', 'daubs'],
#  'deno': ['deon', 'node', 'done'],
#  'aeeilnpst': ['penalties', 'palestine'],
#  'apr': ['rap', 'par', 'apr'],
#  "'ceeiprs": ["recipe's", "pierce's"],
#  'aeeimrst': ['emirates', 'steamier'],
#  "'amsy": ["may's", "yam's", "amy's"],
#  'acelr': ['clare', 'clear'],
#  'aehns': ['ashen', 'shane'],
#  'acdegln': ['glanced', 'clanged'],
#  'eefrs': ['reefs', 'frees'],
#  'aceelrt': ['electra', 'treacle'],
#  'acehnsst': ['stanches', 'snatches', 'chastens'],
#  "'apsy": ["pay's", "yap's"],
#  'aet': ['ate', 'tea', 'eta', 'eat'],
#  'deeimprs': ['premised', 'simpered'],
#  "'imnors": ["morin's", "minor's"],
#  'acot': ['cato', 'taco', 'coat'],
#  'enrt': ['rent', 'tern'],
#  'eiorst': ['sortie', 'tories'],
#  'ceikorst': ['rockiest', 'stockier'],
#  "'aadilns": ["danial's", "dalian's"],
#  "'adilsy": ["lydia's", "daily's"],
#  'achin': ['icahn', 'china', 'chain'],
#  'aaeiilnortz': ['realization', 'rationalize'],
#  "'ehlost": ["hotel's", "helot's"],
#  'adilv': ['vidal', 'advil', 'valid'],
#  'aelrtv': ['travel', 'varlet'],
#  "'aeiprss": ["persia's", "spirea's", "praise's"],
#  'abghinorr': ['abhorring', 'harboring'],
#  "'aailrst": ["altair's", "lariat's"],
#  'aimnnos': ['mansion', 'minoans'],
#  'elrsu': ['lures', 'rules'],
#  "'dorswy": ["dowry's", "rowdy's"],
#  'adeemrst': ['mastered', 'streamed'],
#  'deiilmt': ['delimit', 'limited'],
#  'hosstu': ['shouts', 'souths'],
#  'acers': ['cesar', 'races', 'scare', 'acres', 'cares'],
#  "'aegnrrs": ["ranger's", "garner's"],
#  'cenortu': ['recount', 'trounce', 'counter'],
#  "'abcels": ["cable's", "caleb's"],
#  'aegrt': ['greta', 'great', 'grate'],
#  'acdilnor': ['alcindor', 'ironclad'],
#  'alloy': ['loyal', 'alloy'],
#  "'cefhist": ["fetich's", "fichte's"],
#  'aelnp': ['plane', 'penal', 'nepal', 'panel'],
#  "'ailsty": ["laity's", "italy's"],
#  'eimrst': ['merits', 'remits', 'timers', 'mister', 'miters'],
#  'acellr': ['recall', 'caller', 'cellar'],
#  'adesw': ['dawes', 'wades', 'sawed'],
#  "'acelosv": ["alcove's", "coeval's"],
#  'aeghnopst': ['heptagons', 'pathogens'],
#  'glpu': ['gulp', 'plug'],
#  'acelost': ['locates', 'lactose'],
#  "'aelnos": ["oneal's", "leona's"],
#  "'aims": ["mia's", "mai's", "aim's"],
#  'aehnsy': ['hyenas', 'haynes'],
#  'ceefhist': ['fetiches', 'chiefest'],
#  'aegimr': ['mirage', 'margie', 'gamier'],
#  "'alnoss": ["sloan's", "salon's"],
#  'aint': ['anti', 'tina', 'nita'],
#  'aosstt': ['stoats', 'toasts'],
#  'aanrtt': ['rattan', 'tartan'],
#  "'aekmrs": ["maker's", "merak's"],
#  'acemnor': ['cameron', 'romance'],
#  'bdeilrsu': ['rebuilds', 'builders'],
#  'ainsstu': ['austins', 'sustain'],
#  "'nosw": ["now's", "won's"],
#  "'aeersst": ["easter's", "teaser's", "teresa's"],
#  'aiilnoopst': ['spoliation', 'positional'],
#  'agnst': ['tangs', 'angst', 'gnats'],
#  "'eelrsv": ["revel's", "lever's"],
#  'cdeiorsv': ['divorces', 'discover'],
#  'beghinrt': ['berthing', 'brighten'],
#  'aginorst': ['organist', 'roasting'],
#  "'eiklnsw": ["welkin's", "winkle's"],
#  'bru': ['bur', 'rub'],
#  "'eorsv": ["over's", "rove's"],
#  'enrrtuu': ['nurture', 'untruer'],
#  "'bekoors": ["brooke's", "booker's"],
#  'ahist': ['tisha', 'thais', 'saith'],
#  'aeeglns': ['angeles', 'senegal'],
#  'aeelrs': ['resale', 'sealer', 'reales'],
#  "'cnosstu": ["tuscon's", "tucson's"],
#  'abdennr': ['branden', 'brendan'],
#  'acdepr': ['carped', 'redcap'],
#  'deiorsw': ['weirdos', 'rowdies', 'dowries'],
#  'aaailnrstu': ['australian', 'saturnalia'],
#  'ginorsu': ['souring', 'rousing'],
#  'filt': ['flit', 'lift'],
#  'aenv': ['vane', 'neva', 'nave', 'evan'],
#  'aehr': ['hare', 'hera', 'rhea', 'hear'],
#  "'aelsu": ["laue's", "eula's"],
#  "'chmsu": ["chum's", "much's"],
#  'agims': ['sigma', 'agism'],
#  'eilrvy': ['livery', 'verily'],
#  "'deinnos": ["dionne's", "donnie's"],
#  'amrsw': ['warms', 'swarm'],
#  'aaemnst': ['smetana', 'eastman'],
#  'aghilmorst': ['algorithms', 'logarithms'],
#  'aemnst': ['stamen', 'mantes'],
#  "'eenprsss": ["serpens's", "spenser's"],
#  'aimost': ['maoist', 'taoism'],
#  'aeimnrsu': ['sumerian', 'aneurism', 'suriname'],
#  'aeimnnost': ['minnesota', 'nominates'],
#  "'densu": ["dune's", "nude's"],
#  "'agins": ["gain's", "agni's", "gina's"],
#  'adnor': ['drano', 'norad', 'ronda', 'adorn', 'radon'],
#  "'ailsv": ["vila's", "vial's"],
#  'aeflrsu': ['refusal', 'earfuls'],
#  "'chins": ["chin's", "inch's"],
#  "'almors": ["moral's", "molar's"],
#  "'efins": ["enif's", "fine's"],
#  'acdehnst': ['stanched', 'snatched'],
#  'aelnrtu': ['laurent', 'neutral', 'renault'],
#  'oprst': ['strop', 'ports', 'sport'],
#  'adeeilnt': ['dateline', 'entailed'],
#  'acddeeimt': ['medicated', 'decimated'],
#  'ddefor': ['fodder', 'forded'],
#  'eelps': ['sleep', 'peels'],
#  'aceilsst': ['alcestis', 'elastics', 'scaliest'],
#  'aegilmnr': ['germinal', 'malinger'],
#  'aaprst': ['sparta', 'satrap'],
#  'adgrs': ['grads', 'drags'],
#  'benor': ['boner', 'borne'],
#  "'aalmnosy": ["layamon's", "anomaly's"],
#  "'aeilns": ["aline's", "alien's"],
#  'eiklns': ['likens', 'silken'],
#  "'esx": ["ex's", "xe's"],
#  'aalrst': ['astral', 'altars'],
#  'adeirst': ['tirades', 'astride', 'staider'],
#  'adeilort': ['tailored', 'idolater'],
#  'apssw': ['swaps', 'wasps'],
#  'aaegsssu': ['sausages', 'assuages'],
#  'acdeinoorst': ['coordinates', 'decorations'],
#  'adeinnoostt': ['detonations', 'denotations'],
#  "'aenrsv": ["raven's", "verna's"],
#  'gghinsu': ['huggins', 'gushing'],
#  'aaimnor': ['romania', 'mariano'],
#  'eorsv': ['servo', 'overs', 'roves'],
#  'acfiinnort': ['infarction', 'infraction'],
#  'acns': ['scan', 'cans'],
#  'acerst': ['crates',
#   'reacts',
#   'carets',
#   'traces',
#   'caster',
#   'caters',
#   'recast'],
#  'eisv': ['vise', 'vies', 'ives'],
#  'aeimnor': ['moraine', 'romaine'],
#  'alorv': ['orval', 'valor'],
#  'eiinopstt': ['pointiest', 'petitions'],
#  "'eekns": ["keen's", "knee's"],
#  'einoprt': ['pointer', 'protein'],
#  'eilov': ['voile', 'olive'],
#  'eprrsuu': ['usurper', 'pursuer'],
#  "'aeimnrst": ["minaret's", "raiment's"],
#  'einnost': ['tension', 'intones'],
#  'aeilnsst': ['saltines', 'salients'],
#  'cdeir': ['riced', 'cider', 'cried'],
#  'aberss': ['sabers', 'sabres'],
#  "'egorsu": ["rogue's", "rouge's"],
#  'aceilprs': ['replicas', 'calipers'],
#  'cdeiorrst': ['directors', 'creditors'],
#  "'eelrsstw": ["swelter's", "wrestle's"],
#  'eerv': ['ever', 'veer'],
#  'belorsw': ['bowlers', 'blowers'],
#  'ggiilnns': ['slinging', 'singling'],
#  "'aacclrsu": ["accrual's", "caracul's"],
#  "'aorsst": ["sarto's", "astor's", "roast's"],
#  'aprss': ['spars', 'rasps'],
#  'ainv': ['vain', 'ivan'],
#  'aegmnrs': ['mangers', 'germans'],
#  'einr': ['erin', 'rein'],
#  'deinrs': ['snider', 'rinsed', 'diners'],
#  "'acst": ["cat's", "act's"],
#  "'eopss": ["pose's", "peso's"],
#  'alprty': ['partly', 'paltry'],
#  'oprsst': ['strops', 'sports'],
#  'aeghilnrt': ['haltering', 'lathering', 'earthling'],
#  'beglsu': ['bugles', 'bulges'],
#  'aeill': ['leila', 'allie', 'lelia'],
#  "'arst": ["art's", "rat's", "tar's"],
#  'aekps': ['spake', 'peaks', 'speak'],
#  'coost': ['scoot', 'coots'],
#  "'dehimnoss": ["hedonism's", "sondheim's"],
#  "'aehrstt": ["hatter's", "threat's"],
#  'aprst': ['strap', 'tarps', 'sprat', 'parts', 'traps'],
#  'ddeiov': ['voided', 'devoid'],
#  'acegir': ['gracie', 'cagier'],
#  'aeglmn': ['legman', 'mangle'],
#  "'inpss": ["spin's", "snip's"],
#  "'agrsy": ["gary's", "gray's"],
#  'alsst': ['salts', 'lasts', 'slats'],
#  'cdeikr': ['derick', 'dicker', 'ricked'],
#  'bcehrstu': ['butchers', 'schubert'],
#  'eenst': ['teens', 'tense'],
#  'eorstv': ['strove', 'voters'],
#  'lost': ['slot', 'lots', 'lost'],
#  'afilr': ['frail', 'flair'],
#  'efirst': ['refits', 'rifest', 'strife', 'sifter'],
#  "'ehirs": ["heir's", "hire's"],
#  'acst': ['cats', 'cast', 'acts', 'scat'],
#  'ademosy': ['someday', 'samoyed'],
#  'einrssu': ['sunrise', 'insures'],
#  'eeinrstv': ['reinvest', 'nerviest'],
#  'adenpps': ['appends', 'snapped'],
#  "'aglnos": ["logan's", "golan's", "anglo's"],
#  'eeerrssv': ['reverses', 'reserves'],
#  'deeepst': ['deepest', 'steeped'],
#  "'anps": ["nap's", "pan's"],
#  'inptu': ['input', 'putin'],
#  'ehos': ['hoes', 'shoe', 'hose'],
#  "'degirs": ["dirge's", "ridge's"],
#  "'efhlss": ["shelf's", "flesh's"],
#  'aclos': ['colas', 'coals'],
#  'efil': ['life', 'file', 'leif', 'lief'],
#  'eimrs': ['miser', 'mires', 'emirs', 'rimes'],
#  "'aaglnos": ["angola's", "analog's"],
#  'enos': ['nose', 'ones', 'enos', 'noes', 'eons'],
#  'adeinrst': ['strained', 'randiest'],
#  'ablms': ['lambs', 'balms'],
#  'fnotu': ['fount', 'futon'],
#  "'ajnoss": ["sonja's", "jonas's", "jason's"],
#  "'acdeiimnost": ["decimation's", "medication's"],
#  'deeeirs': ['desiree', 'seedier'],
#  'acdir': ['dirac', 'acrid'],
#  'emost': ['tomes', 'motes', 'smote'],
#  'aceorstv': ['overcast', 'overacts'],
#  'illps': ['pills', 'spill'],
#  "'eenrsst": ["sterne's", "ernest's"],
#  'achiinrst': ['christina', 'christian'],
#  'agiilnn': ['nailing', 'alining'],
#  'adeelpry': ['replayed', 'parleyed'],
#  'aceiltt': ['tactile', 'lattice'],
#  "'adilsv": ["advil's", "vidal's"],
#  'aegginnr': ['angering', 'enraging'],
#  'aegmnr': ['german', 'manger'],
#  'abelort': ['latrobe', 'alberto'],
#  'arstt': ['start', 'tarts'],
#  "'eorstt": ["otter's", "torte's"],
#  "'aerst": ["tear's", "tare's", "rate's"],
#  'abeeilns': ['baseline', 'balinese'],
#  'emos': ['some', 'emos'],
#  'aehsy': ['yeahs', 'hayes'],
#  'adeeiln': ['adeline', 'aliened'],
#  'aemss': ['mesas', 'sames', 'seams'],
#  'aps': ['sap', 'pas', 'spa', 'asp'],
#  'aenprt': ['entrap', 'parent'],
#  "'ghirst": ["right's", "girth's"],
#  'aamnn': ['manna', 'annam'],
#  'ilopst': ['spoilt', 'pilots', 'pistol'],
#  'ggiknos': ['ginkgos', 'gingkos'],
#  'eimorst': ['moister', 'mortise'],
#  "'belmmrsu": ["brummel's", "mumbler's"],
#  'adegp': ['gaped', 'paged'],
#  'eoqtu': ['quote', 'toque'],
#  ...}

# %%
print(all_anagram_lists(word_list))
# Out:
# 93406
# 93406
# [('cegimnoorv', [1, 'overcoming']), ('adeemn', [1, 'demean']), ('acdiisst', [1, 'sadistic']), ('acdeghimoprs', [1, 'demographics']), ('ackrst', [1, 'tracks']), ('aceipprst', [1, 'crappiest']), ('ehimrsu', [1, 'mushier']), ("'eginsv", [1, "given's"]), ("'aghilnsw", [1, "whaling's"]), ('adeinst', [3, 'detains', 'instead', 'stained']), ('ceeeilmnnopsst', [1, 'incompleteness']), ("'abcilmoos", [1, "colombia's"]), ("'aaklmnnss", [1, "klansman's"]), ('accelno', [1, 'conceal']), ("'defiinrsw", [1, "winifred's"]), ('eeeilnrsy', [1, 'eyeliners']), ('aahinoorr', [1, 'honoraria']), ('aeksst', [3, 'stakes', 'skates', 'steaks']), ('aeghilr', [1, 'raleigh']), ("'acdeinorstt", [1, "detraction's"]), ('adfrru', [1, 'darfur']), ('ghinrsu', [1, 'rushing']), ('accdeeioprrt', [1, 'reciprocated']), ('agiinnst', [1, 'staining']), ('ehlooprst', [1, 'portholes']), ('ddelmo', [1, 'molded']), ('aeiiprtvz', [1, 'privatize']), ("'ceeeilnss", [1, "licensee's"]), ("'aegorstu", [1, "outrage's"]), ('egrsu', [2, 'urges', 'surge']), ('denoprs', [2, 'ponders', 'respond']), ("'eikrst", [1, "trike's"]), ('eorrttt', [1, 'trotter']), ('eeiilnrst', [2, 'listerine', 'resilient']), ("'aadimors", [1, "diorama's"]), ('acelorrsu', [1, 'carrousel']), ('admnoosst', [1, 'mastodons']), ("'ehisv", [1, "hive's"]), ("'achlprstu", [1, "plutarch's"]), ('adgmnoo', [1, 'goodman']), ('effgiinnst', [1, 'stiffening']), ('berttu', [1, 'butter']), ('acgghhiijkn', [1, 'highjacking']), ('adeelpr', [2, 'pleader', 'pearled']), ('bgilnnotu', [1, 'unbolting']), ('bdeelss', [1, 'blessed']), ('bdeorsw', [1, 'browsed']), ("'ceemnnnosttt", [1, "contentment's"]), ('acdeeilnrt', [2, 'interlaced', 'credential']), ('elrsy', [2, 'lyres', 'slyer']), ('aabeegllt', [1, 'bagatelle']), ("'elsvy", [1, "levy's"]), ('aellnnotw', [1, 'allentown']), ("'eeeepsw", [1, "peewee's"]), ('aeghoopprrt', [1, 'topographer']), ('bcdhiotw', [1, 'bowditch']), ('abginot', [1, 'boating']), ('addeimnot', [1, 'dominated']), ("'aefst", [3, "feat's", "feta's", "fate's"]), ('ahns', [2, 'nash', 'hans']), ("'deehirsty", [1, "heredity's"]), ("'ceklos", [1, "locke's"]), ('gilnt', [1, 'glint']), ('cdegilnnooprrsy', [1, 'correspondingly']), ("'aasv", [1, "ava's"]), ('aabfiknrs', [1, 'fairbanks']), ('abcceilssy', [1, 'accessibly']), ("'cgos", [1, "cog's"]), ('aaegst', [1, 'agates']), ('bdeel', [1, 'bleed']), ('bikkorsyz', [1, 'korzybski']), ('aabemrsttu', [1, 'masturbate']), ('aceeghilprt', [1, 'telegraphic']), ('aaeilnorstx', [1, 'relaxations']), ("'aefhmorssu", [1, "farmhouse's"]), ('aaaahjmrs', [1, 'maharajas']), ('adeiilqstu', [1, 'liquidates']), ('bbcdeelor', [1, 'clobbered']), ('aeegimnnruv', [1, 'maneuvering']), ('ennnruy', [1, 'nunnery']), ("'imnoooprst", [1, "promotion's"]), ('abdeinrtttuu', [1, 'unattributed']), ("'aeiilnrsstuvy", [1, "universality's"]), ("'achiirrstt", [1, "arthritic's"]), ('blrsu', [1, 'blurs']), ('abgloru', [1, 'borlaug']), ('dehikmoss', [1, 'sheikdoms']), ('aknró', [1, 'króna']), ('adlnou', [1, 'unload']), ('lmqsy', [1, 'mysql']), ("'gips", [1, "pig's"]), ('aeghilnootz', [1, 'anthologize']), ('biklnost', [1, 'inkblots']), ('deioorsw', [1, 'woodsier']), ('amps', [3, 'amps', 'maps', 'spam']), ("'airssy", [1, "syria's"]), ('eegilnr', [2, 'leering', 'reeling']), ('cdehiimos', [1, 'homicides']), ('bberrruy', [1, 'burberry']), ('abos', [1, 'boas']), ("'eeilsss", [1, "lessie's"]), ('aaelmt', [1, 'tamale']), ('aeorssu', [1, 'arouses']), ('enorss', [2, 'sensor', 'snores']), ("'einrstw", [1, "winter's"]), ("'aaeeegmnnprrrst", [1, "prearrangement's"]), ("'imnoorst", [1, "monitor's"]), ('beeils', [1, 'belies']), ("'beillnorst", [1, "bertillon's"]), ('abiortv', [1, 'vibrato']), ("'ceeehllsssy", [1, "seychelles's"]), ("'aelmrsy", [1, "marley's"]), ("'aces", [1, "ace's"]), ('eikm', [1, 'mike']), ('aeeijmsst', [1, 'majesties']), ('dfhlnoosuw', [1, 'wolfhounds']), ('bdeinrs', [2, 'binders', 'rebinds']), ("'adeeeghhilnrssstt", [1, "lightheartedness's"]), ('ceeefkllorr', [1, 'rockefeller']), ('giilnstu', [1, 'linguist']), ('ae ...

# %%
# %time anagram_map = all_anagram_lists(word_list)
# Out:
# 93406
# 93406
# CPU times: user 342 ms, sys: 40 ms, total: 382 ms
# Wall time: 375 ms

# %%
len(anagram_map)
#print(anagram_map)
# Out:
# 93406

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
# Original program already does this

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
word_found = False
i = 0
# Simple function to return the length of the key
def get_len(key):
    return len(key[0])

# Finds anagrams in the list provided
anagram_dict = all_anagram_lists(word_list)
  
# Turns the dictionary to a list of tuples
anagram_dict_list = list(anagram_dict.items())
# Sorts the list of tuples based on word length
anagram_dict_list.sort(reverse = True, key = get_len)
# Turning list back to a dictionary
#sorted_dict = {ele[0] : ele[1]  for ele in anagram_dict_list}

while word_found == False:
    item = [anagram_dict_list[i][0]]
    if len(item) >= 2:
        word_found = True
        word = anagram_dict_list[i][0]
    else:
        i += 1
        print(i)
print(word)
# printing result 
#print(sorted_dict)
# Out:
# 93406
# 93406
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [22], line 11
#       8 anagram_dict = all_anagram_lists(word_list)
#      10 # Turns the dictionary to a list of tuples
# ---> 11 anagram_dict_list = list(anagram_dict.items())
#      12 # Sorts the list of tuples based on word length
#      13 anagram_dict_list.sort(reverse = True, key = get_len)
#
# AttributeError: 'list' object has no attribute 'items'

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
