# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False
 # True
# Out:
# True

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 1.41 µs ± 43.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 4.53 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False


def all_anagram_pairs(word_list):
    word_count = len(word_list)
    i = 0
    pairs = []

    while i != word_count:
        checking = word_list[i]
        for word in word_list:
            if word == checking:
                continue
            elif is_anagram(checking, word):
                pairs.append((checking, word))
        i += 1
    
    pair_count = len(pairs)
        
        
    return pairs

all_anagram_pairs(short_word_list)
# Out:
# [('proudest', 'sprouted'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('pots', 'stop'),
#  ('pots', 'tops'),
#  ('tops', 'stop'),
#  ('tops', 'pots'),
#  ('sprouted', 'proudest')]

# %%
all_anagram_pairs(short_word_list)

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')
# Out:
# Downloaded american-english

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
# pairs = all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    anagrams = {}

    # Loop over the list of words
    for word in word_list:
        # Rearrange the word so that each letter is in alphabetical order 
        sorted_word = ''.join(sorted(word))
        # Check if the resorted word is already a key in the dictionary 
        if not anagrams.get(sorted_word):
            # Create a key with the resorted word if it is not and add the normal unsorted word as a value
            anagrams.update({sorted_word: [word]})
        else:
            # Just add the unsorted word as a value to the already existing key
            anagrams[sorted_word].append(word)
    
    # Turn the dictionary into a list of tuples
    anagrams_list = list(anagrams.items())
    # Save the list
    store_anagrams_list = anagrams_list
    # Loop through the list
    for ele in anagrams_list:
        # If length of the second value of the tuple is 1 then remove it from the list
        if len(ele[1]) == 1:
            store_anagrams_list.remove(ele)
        
    # Turn the list back into a dictionary        
    true_anagrams = {ele[0] : ele[1]  for ele in store_anagrams_list}
    # Return the dictionary
    return true_anagrams

# %%
# %time anagram_map = all_anagram_lists(word_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In [5], line 28, in all_anagram_lists(word_list)
#      25 for ele in anagrams_list:
#      26     # If length of the second value of the tuple is 1 then remove it from the list
#      27     if len(ele[1]) == 1:
# ---> 28         store_anagrams_list.remove(ele)
#      30 # Turn the list back into a dictionary
#      31 true_anagrams = {ele[0] : ele[1]  for ele in store_anagrams_list}
#
# KeyboardInterrupt:

# %%
len(anagram_map)
#print(anagram_map)
# Out:
# 93406

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
# Original program already does this

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
def get_len(key):
    return len(key[0])

anagram_dict = all_anagram_lists(word_list)
  
# sorting using sort()
# external to render logic 
anagram_dict_list = list(anagram_dict.items())
anagram_dict_list.sort(reverse = True, key = get_len)
  
# reordering to dictionary
sorted_dict = {ele[0] : ele[1]  for ele in anagram_dict_list}
  
# printing result 
print(sorted_dict)
# Out:
# {"'aacceeeeghhllnoopprrst": ["electroencephalograph's"], 'aceeeiilnnooorrrsttuuv': ['counterrevolutionaries'], "'cceeeegiillnnnorsttu": ["counterintelligence's"], 'aaacccehiillnrrsttuy': ['uncharacteristically'], 'aacceeeeghllmnooprrt': ['electroencephalogram'], "'aaccdeeghilooprrrst": ["electrocardiograph's"], "'acdeeefhiimnnnrssst": ["disenfranchisement's"], "'aaabiinnnorsssttttu": ["transubstantiation's"], "'acefiiiilmnooprsstv": ["oversimplification's"], 'aceeilnnooorrrttuuvy': ['counterrevolutionary'], "'aacceiiilmmnoorstz": ["commercialization's"], "'ccdeiinoprssttuuvy": ["superconductivity's"], "'aaeehiinorssstttuv": ["authoritativeness's"], "'aacceiilnnoopsttuz": ["conceptualization's"], "'aeeiiimnnoprrssttt": ["misinterpretation's"], "'aaccdeegilmoorrrst": ["electrocardiogram's"], "'ceeilnnooorrsttuuv": ["counterrevolution's"], "'cceiinnnoopsssssuu": ["inconspicuousness's"], "'acdeeeiinnnorsssst": ["inconsiderateness's"], "'aaceggiilnnoorsstt": ["congregationalist's"], "'aacdeiiiilmnnorstz": ["decriminalization's"], 'acefiiiilmnooprsstv': ['oversimplifications'], "'ceeeehimnnoprssssv": ["comprehensiveness's"], "'acceehillllnorssv": ["chancellorsville's"], "'acdeefhiimnnrssst": ["disfranchisement's"], "'aaccgiiimnnorstuv": ["circumnavigation's"], "'aaaccehiinorrsttz": ["characterization's"], "'addegiimnnnrssstu": ["misunderstanding's"], "'aeefiilmnooprssss": ["semiprofessional's"], 'aacegiilmmnnoprttz': ['compartmentalizing'], 'aeeeiimnnoprrssstt': ['misrepresentations'], 'aeehiiilnnoprrsstt': ['interrelationships'], 'aaegiiiilnnnnorttz': ['internationalizing'], "'aefiilnnnoooprrst": ["nonproliferation's"], "'aeeiilmnnnorssttv": ["environmentalist's"], "'bdehiilnoorsssstt": ["bloodthirstiness's"], 'eeehiiiinprsssttvy': ['hypersensitivities'], "'aeeiilmmnnnorsstv": ["environmentalism's"], "'aefiilmnorsssstuu": ["multifariousness's"], 'adeiilnooopprrstty': ['disproportionately'], "'bciiiilnoprrsttuy": ["incorruptibility's"], 'acefiiiilmnooprstv': ['oversimplification'], 'aaceeilnorrssttuvv': ['ultraconservatives'], "'aaiiimnooppprrsst": ["misappropriation's"], 'aacdeeilnnnrsssttt': ['transcendentalists'], "'aeeeiinnoprrrsttt": ["reinterpretation's"], "'aaeeeilrrrrsstttx": ["extraterrestrial's"], "'aaaefilnoopprrsss": ["paraprofessional's"], "'aaeiiilmnnnorsstt": ["internationalism's"], "'eehiiinprsssttvyy": ["hypersensitivity's"], "'aabiiilnnnnostttu": ["tintinnabulation's"], "'ahhimmnooopprrsst": ["anthropomorphism's"], 'aaccdeeghilooprrrt': ['electrocardiograph'], "'aaahiiimnorrssttu": ["authoritarianism's"], 'aaacccehiillrrstty': ['characteristically'], "'aacdfiiiilnoqsstu": ["disqualification's"], "'aciilllmmrssttuuu": ["multiculturalism's"], 'acdeeefhiimnnnrsst': ['disenfranchisement'], "'aceeeginnooprsstu": ["counterespionage's"], 'aaccdeegilmoorrrst': ['electrocardiograms'], "'aceeimnnoooprsstv": ["overcompensation's"], "'celnnoprsssssuuuu": ["unscrupulousness's"], "'adeeeiimnnoprrstt": ["predetermination's"], 'aceegiiilllnnttuz': ['intellectualizing'], "'aaceeghimnoprrst": ["cinematographer's"], 'aciiimnnnooprsstu': ['mispronunciations'], "'cdeeeinrssssttuv": ["destructiveness's"], "'cddeeeeeinnnprst": ["interdependence's"], 'aaiiimnooppprrsst': ['misappropriations'], 'aaeeeilrrrrsstttx': ['extraterrestrials'], 'aaeeiiilnnnorsttz': ['internationalizes'], 'aacdeeilmnnnrsstt': ['transcendentalism'], "'aceiinnoorsssttv": ["conservationist's"], "'acdeeegklmnnostw": ["acknowledgement's"], "'abcceiiiilnsssty": ["inaccessibility's"], 'bceehiiilmnoprsty': ['comprehensibility'], "'ceehiimnosssssuv": ["mischievousness's"], 'acdeeeiinnnorssst': ['inconsiderateness'], 'aaaddegilnosstuvy': ['disadvantageously'], 'aeeeiimnnoprrsstt': ['misrepresentation'], "'ehinorrsssstttuw": ["trustworthiness's"], "'acdefiiilnnostty": ["confidentiality's"], "'aghhillmooopsstt": ["ophthalmologist's"], "'deeeinnnossssttu": ["tendentiousness's"], 'ccdeeinooprrttuuv': ['counterproductive'], "'acdefiiiinorsstv": ["diversification's"], 'aacceiiilm ...

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
