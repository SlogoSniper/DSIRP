# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False
 # True

# %%
is_anagram('tachymetric', 'mccarthyite') # True

# %%
is_anagram('post', 'top') # False, letter not present

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies

# %%
is_anagram('top', 'post') # False, letters left over at the end

# %%
is_anagram('topss', 'postt') # False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

def is_anagram(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    i = 0

    if len1 == len2:
        counter1 = 0
        counter2 = 0
        char1 = [*word1]
        char2 = [*word2]
        
        while i < len1:
            for letter in char1:
                if char2.count(letter) > 0 and char1.count(letter) == char2.count(letter):
                    char1.remove(letter)
                    char2.remove(letter)
                else:
                    break
            i += 1    

        if len(char1) == 0 and len(char2) == 0:
            return True
        else:
            return False
    else:
        return False


def all_anagram_pairs(word_list):
    word_count = len(word_list)
    i = 0
    pairs = []

    while i != word_count:
        checking = word_list[i]
        for word in word_list:
            if word == checking:
                continue
            elif is_anagram(checking, word):
                pairs.append((checking, word))
        i += 1
    
    pair_count = len(pairs)
        
        
    return pairs

all_anagram_pairs(short_word_list)

# %%
all_anagram_pairs(short_word_list)

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
# pairs = all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """
    anagrams = {}

    # Loop over the list of words
    for word in word_list:
        # Rearrange the word so that each letter is in alphabetical order 
        sorted_word = ''.join(sorted(word))
        # Check if the resorted word is already a key in the dictionary 
        if not anagrams.get(sorted_word):
            # Create a key with the resorted word if it is not and add the normal unsorted word as a value
            anagrams.update({sorted_word: [1, word]})
        else:
            # Just add the unsorted word as a value to the already existing key
            anagrams[sorted_word].append(word)
            anagrams[sorted_word][0] += 1
    
    # Turn the dictionary into a list of tuples
    anagrams_list = list(anagrams.items())
    length = len(anagrams_list) - 1    
    # Save the list
    store_anagrams_list = anagrams_list
    # Loop through the list for each element in anagrams_list:
    while length != -1:
        # If length of the second value of the tuple is 1 then remove it from the list
        if anagrams_list[length][1][0] == 1:
            store_anagrams_list.remove(anagrams_list[length])
            length -= 1
        else:
            # Clean up the list by removing coutner element
            del store_anagrams_list[length][1][0]
            length -= 1
        
    # Turn the list back into a dictionary        
    true_anagrams = {ele[0] : ele[1]  for ele in store_anagrams_list}
    # Return the dictionary
    return true_anagrams

# %%
# %time anagram_map = all_anagram_lists(word_list)

# %%
len(anagram_map)
#print(anagram_map)

# %%
anagram_map = all_anagram_lists(word_list)

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
# Original program already does this

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
word_found = False
i = 0
# Simple function to return the length of the key
def get_len(key):
    return len(key[0])

def get_sorted(ana_dict):
    # Turns the dictionary to a list of tuples
    anagram_dict_list = list(ana_dict.items())
    # Sorts the list of tuples based on word length
    anagram_dict_list.sort(reverse = True, key = get_len)
    # Turning list back to a dictionary
    sorted_dict = {ele[0] : ele[1]  for ele in anagram_dict_list}
    return sorted_dict

def get_longest(dict):
    # Turns the dictionary to a list of tuples
    anagram_dict_list = list(dict.items())
    # Sorts the list of tuples based on word length
    anagram_dict_list.sort(reverse = True, key = get_len)
    return anagram_dict_list[0][1]



get_longest(anagram_map)
get_sorted(anagram_map)
# Out:
# {"'eeeiimnprsssssv": ["permissiveness's", "impressiveness's"],
#  "'accefiiinorstt": ["rectification's", "certification's"],
#  "'aaeehhimprstt": ["amphitheatre's", "amphitheater's"],
#  "'aceinnoorsstv": ["conversation's", "conservation's"],
#  'accefiiinorstt': ['rectifications', 'certifications'],
#  'eeeiimnprssssv': ['impressiveness', 'permissiveness'],
#  'abefllnoopsstu': ['tablespoonfuls', 'tablespoonsful'],
#  'aaeehhimprstt': ['amphitheaters', 'amphitheatres'],
#  'acceemnorsttu': ['accoutrements', 'accouterments'],
#  "'aabcdeorrsst": ["broadcaster's", "rebroadcast's"],
#  'ceefiimnoprst': ['imperfections', 'perfectionism'],
#  "'aciillnoosst": ["colonialist's", "oscillation's"],
#  "'acdefiiinost": ["edification's", "deification's"],
#  'aaceiilnprstt': ['paternalistic', 'antiparticles'],
#  'accefiiinortt': ['certification', 'rectification'],
#  "'aceeiipprstt": ["precipitate's", "peripatetic's"],
#  "'aeeimnnorstu": ["mountaineer's", "enumeration's"],
#  "'aaeinoprrst": ["praetorian's", "reparation's"],
#  "'aeeinnorstv": ["veneration's", "enervation's"],
#  'cdeiimmnooss': ['commissioned', 'decommission'],
#  "'acdeiimnost": ["decimation's", "medication's"],
#  'aceeiipprstt': ['peripatetics', 'precipitates'],
#  'cdeiinnoorst': ['reconditions', 'conditioners'],
#  'adeeimnoprst': ['impersonated', 'predominates'],
#  "'eiimnoprsss": ["impression's", "permission's"],
#  'eeiilmprssvy': ['impressively', 'permissively'],
#  'aabcdeorrsst': ['broadcasters', 'rebroadcasts'],
#  'aaeehhimprtt': ['amphitheatre', 'amphitheater'],
#  'aeeimnnorstu': ['mountaineers', 'enumerations'],
#  'aeeinnoprstt': ['presentation', 'penetrations'],
#  'eehloprrsstu': ['reupholsters', 'upholsterers'],
#  "'acdeinoorst": ["decoration's", "coordinate's"],
#  "'eeiinoprstt": ["petitioner's", "repetition's"],
#  'aabdehhirrst': ['hairsbreadth', 'hairbreadths'],
#  "'deiinnosstt": ["distention's", "tendonitis's"],
#  'aceeeilmnpst': ['mantlepieces', 'mantelpieces'],
#  'aceinnoorstv': ['conversation', 'conservation'],
#  'eeeinprrrstt': ['reinterprets', 'interpreters'],
#  "'adeinnoostt": ["denotation's", "detonation's"],
#  "'aaginnosstt": ["stagnation's", "antagonist's"],
#  "'aeehinrssst": ["heartiness's", "earthiness's"],
#  'aciillnoosst': ['oscillations', 'colonialists'],
#  'aaeiilnorstt': ['retaliations', 'aristotelian'],
#  "'adiimnnoost": ["admonition's", "domination's"],
#  "'acfiinnorst": ["infraction's", "infarction's"],
#  'aeflnoopsstu': ['teaspoonsful', 'teaspoonfuls'],
#  "'afiilnorstt": ["flirtation's", "filtration's"],
#  "'aaailnrsstu": ["saturnalia's", "australian's"],
#  'acdeilnoosst': ['disconsolate', 'consolidates'],
#  "'adeehilprss": ["leadership's", "dealership's"],
#  "'cdeeirsttu": ["rectitude's", "certitude's"],
#  'adeeilmnrst': ['derailments', 'streamlined'],
#  'eegiinnnrtv': ['reinventing', 'intervening'],
#  "'deinorsssw": ["wordiness's", "rowdiness's"],
#  "'aghilmorst": ["logarithm's", "algorithm's"],
#  'aeimnoprttu': ['importunate', 'permutation'],
#  "'ehkoorssuw": ["workhouse's", "housework's"],
#  "'cgiinnoost": ["cognition's", "incognito's"],
#  'aaeiilnortz': ['realization', 'rationalize'],
#  'acdeinoorst': ['coordinates', 'decorations'],
#  'adeinnoostt': ['detonations', 'denotations'],
#  'eiimnoprsss': ['impressions', 'permissions'],
#  'acdefiiinot': ['edification', 'deification'],
#  "'ghilopsstt": ["stoplight's", "spotlight's"],
#  'eeiinoprstt': ['repetitions', 'petitioners'],
#  'cdeeeoprrss': ['reprocessed', 'predecessor'],
#  'aacggilnotu': ['cataloguing', 'coagulating'],
#  "'aceilnosst": ["coastline's", "sectional's"],
#  "'adefilnost": ["defoliant's", "deflation's"],
#  "'accehimsst": ["schematic's", "catechism's"],
#  'cdeiinnoort': ['conditioner', 'recondition'],
#  'eeeinprrsst': ['intersperse', 'enterprises'],
#  "'deeinrssst": ["tiredness's", "dissenter's"],
#  "'aeeginnrst": ["argentine's", "tangerine's"],
#  'aiilmnosttu': ['mutilations', 'stimulation'],
#  'aacghillpry': ['calligraphy', 'graphically'],
#  'aaeilmnprst': ['paternalism', 'parliaments'],
#  'eeeioprrrst': ['repertories', 'repertoires'],
#  "'ceehiknrst": ["thickener's", "kitchener's"],
#  'cdeeiorrssv': ['rediscovers', 'discoverers'],
#  "'aeilnsssst": ["stainless's", "saltiness's"],
#  'aeeiimprstv': ['semiprivate', 'imperatives'],
#  'adeiinoprtt': ['partitioned', 'trepidation'],
#  'aeeimnnortu': ['enumeration', 'mountaineer'],
#  "'adeinrssst": ["streisand's", "tardiness's"],
#  'acghiilmort': ['logarithmic', 'algorithmic'],
#  'eeeinprrrtt': ['interpreter', 'reinterpret'],
#  'aciillnoost': ['colonialist', 'oscillation'],
#  "'aiinnorstu": ["ruination's", "urination's"],
#  'aegiinnrstt': ['reinstating', 'straitening'],
#  "'cehinopsst": ["ctesiphon's", "phonetics's"],
#  'aabcdeorrst': ['broadcaster', 'rebroadcast'],
#  "'aeelprsstt": ["saltpetre's", "saltpeter's"],
#  "'aaceinrsst": ["sectarian's", "cartesian's"],
#  "'aginpprsst": ["trappings's", "strapping's"],
#  "'eeilmnosst": ["milestone's", "limestone's"],
#  "'aeemnssttt": ["testament's", "statement's"],
#  "'abddeiorss": ["sideboard's", "broadside's"],
#  "'accehimnss": ["mischance's", "mechanics's"],
#  'aegiinnortt': ['orientating', 'integration'],
#  "'ceilnorssu": ["inclosure's", "cornelius's"],
#  'aceeiipprtt': ['peripatetic', 'precipitate'],
#  'eehloprrstu': ['reupholster', 'upholsterer'],
#  "'aceinssstt": ["cattiness's", "tacitness's"],
#  'aceeeilmnpt': ['mantlepiece', 'mantelpiece'],
#  'aceinooprrt': ['incorporate', 'procreation'],
#  'abceefiilrt': ['rectifiable', 'certifiable'],
#  'acdeeinorst': ['considerate', 'desecration'],
#  'adeeimnnost': ['emendations', 'denominates'],
#  "'adeforrstw": ["afterword's", "waterford's"],
#  "'aeeilmnnst": ["alinement's", "lineament's"],
#  "'eeloprssty": ["polyester's", "proselyte's"],
#  'aeeilntttvy': ['attentively', 'tentatively'],
#  "'achiinrsst": ["christian's", "christina's"],
#  'aeghilnoost': ['theologians', 'anthologies'],
#  'cdeiinoprst': ['predictions', 'description'],
#  'acdeeilnrt': ['interlaced', 'credential'],
#  'deeeiprstx': ['preexisted', 'expediters'],
#  'acdegiimnt': ['medicating', 'decimating'],
#  "'cdeiorrst": ["director's", "creditor's"],
#  "'aegginors": ["georgina's", "georgian's"],
#  'deeeinnrtv': ['intervened', 'reinvented'],
#  'aceeinrsst': ['ancestries', 'resistance'],
#  'degilnostu': ['longitudes', 'ungodliest'],
#  'aeegimnprt': ['permeating', 'impregnate'],
#  'adeinnoott': ['detonation', 'denotation'],
#  'adeeginnrs': ['grenadines', 'serenading'],
#  "'adeoprrst": ["predator's", "teardrop's"],
#  'aaceinrsst': ['ascertains', 'sectarians'],
#  'eeiimprssv': ['permissive', 'impressive'],
#  "'aceehrrss": ["research's", "searcher's"],
#  "'aaeimnnrs": ["armenian's", "marianne's", "annmarie's"],
#  'aiilnoopst': ['spoliation', 'positional'],
#  'aaailnrstu': ['australian', 'saturnalia'],
#  'aghilmorst': ['algorithms', 'logarithms'],
#  'acfiinnort': ['infarction', 'infraction'],
#  "'dehimnoss": ["hedonism's", "sondheim's"],
#  'cdeiinorst': ['discretion', 'directions'],
#  'egilmnooss': ['gloominess', 'neologisms'],
#  'adegiilmns': ['misleading', 'misdealing'],
#  "'ailmrsstu": ["altruism's", "muralist's"],
#  "'abegmnosy": ["bogeyman's", "moneybag's"],
#  'eeiinoprtt': ['petitioner', 'repetition'],
#  "'aceilnors": ["caroline's", "cornelia's"],
#  'aabeiilnst': ['insatiable', 'banalities'],
#  "'aaceimnrs": ["cinerama's", "american's"],
#  'eeglnorstt': ['longstreet', 'lorgnettes'],
#  "'acciorsst": ["acrostic's", "socratic's"],
#  "'aacellmrs": ["marcella's", "carmella's"],
#  "'aainprsst": ["partisan's", "aspirant's"],
#  "'aeelmnsss": ["lameness's", "maleness's"],
#  "'aegilnssv": ["leavings's", "svengali's"],
#  'aehirssttw': ['swarthiest', 'sweatshirt'],
#  "'acdilnors": ["ironclad's", "alcindor's"],
#  "'deeinrsst": ["dniester's", "resident's"],
#  'deginnrssu': ['undersigns', 'undressing'],
#  "'aceinorst": ["reaction's", "creation's"],
#  'cefginorsu': ['configures', 'refocusing'],
#  "'aeginnost": ["antigone's", "negation's"],
#  'aceeilmsst': ['timescales', 'clematises'],
#  'aacdeglotu': ['catalogued', 'coagulated'],
#  "'''cefloss": ["fo'c's'les", "fo'c'sle's"],
#  'adiimnnoot': ['admonition', 'domination'],
#  "'aeeeprrst": ["repartee's", "repeater's"],
#  "'aabdlorrs": ["labrador's", "larboard's"],
#  'aeeilmnnst': ['alinements', 'lineaments'],
#  'eimnnrsttu': ['instrument', 'nutriments'],
#  "'aachimrss": ["charisma's", "archaism's"],
#  'ceginnnott': ['contingent', 'contenting'],
#  "'ceeorrssu": ["recourse's", "resource's"],
#  'aeghinrstt': ['straighten', 'shattering'],
#  'adeeimnnot': ['emendation', 'denominate'],
#  'aeginrrstt': ['registrant', 'restarting'],
#  'aaeilnorst': ['senatorial', 'rationales'],
#  'cceeginort': ['egocentric', 'geocentric'],
#  'aeehorssuw': ['housewares', 'warehouses'],
#  "'aadeginrs": ["gardenia's", "drainage's"],
#  'ceiinnopst': ['inspection', 'inceptions'],
#  "'bdelloors": ["bordello's", "doorbell's"],
#  "'acilnorst": ["contrail's", "cilantro's"],
#  'cdeeiorrsv': ['rediscover', 'discoverer'],
#  'acgillnops': ['collapsing', 'scalloping'],
#  "'aceenrrst": ["recreant's", "terrance's"],
#  "'eginnorst": ["ringtone's", "nitrogen's"],
#  "'begilnsss": ["glibness's", "blessing's"],
#  "'aeghnopst": ["pathogen's", "heptagon's"],
#  'cddeinostu': ['deductions', 'discounted'],
#  'cceginnort': ['concerting', 'concreting'],
#  "'ceehillns": ["hellenic's", "chenille's"],
#  'aceiinottx': ['excitation', 'intoxicate'],
#  "'aeemnssst": ["tameness's", "massenet's"],
#  'deiinnostt': ['tendonitis', 'distention'],
#  'aeeinnortv': ['veneration', 'enervation'],
#  'aeghilnrst': ['earthlings', 'slathering'],
#  "'ceenorssv": ["converse's", "conserve's"],
#  'aceeinnrst': ['transience', 'nectarines'],
#  "'aacinorst": ["raincoat's", "croatian's"],
#  'ghilopsstt': ['spotlights', 'stoplights'],
#  'adeforrstw': ['forwardest', 'afterwords'],
#  'afiilnortt': ['flirtation', 'filtration'],
#  "'eeinrstty": ["entirety's", "eternity's"],
#  'eeloprssty': ['proselytes', 'polyesters'],
#  'aegiinnprt': ['pertaining', 'repainting'],
#  'ceinoprssu': ['supersonic', 'percussion'],
#  "'aeilnorst": ["oriental's", "relation's"],
#  'aaeinoprrt': ['reparation', 'praetorian'],
#  "'aeoprsssv": ["overpass's", "passover's"],
#  "'aacimnors": ["marciano's", "macaroni's"],
#  'cceeghiknr': ['rechecking', 'checkering'],
#  'cdeeoprrsu': ['procedures', 'reproduces'],
#  'aaceglostu': ['catalogues', 'coagulates'],
#  'aegmoprrrs': ['reprograms', 'programers'],
#  'aeeginnrtv': ['enervating', 'venerating'],
#  "'ailorssty": ["solitary's", "royalist's"],
#  "'eeenprsst": ["pretense's", "petersen's"],
#  'abddeiorss': ['sideboards', 'broadsides'],
#  'deefiilnrs': ['infielders', 'friendlies'],
#  "'abeeilnss": ["balinese's", "baseline's"],
#  'eehmnoorsw': ['homeowners', 'horsewomen'],
#  "'aillorstt": ["tortilla's", "littoral's"],
#  "'ailmnopsy": ["olympian's", "palimony's"],
#  'ceginnortu': ['recounting', 'countering'],
#  'aceilnosst': ['coastlines', 'sectionals'],
#  'egiinprsst': ['springiest', 'persisting'],
#  'acdeiiprst': ['pediatrics', 'patricides'],
#  'aeemnssttt': ['statements', 'testaments'],
#  "'aeghnorsv": ["hangover's", "overhang's"],
#  'aceghinrtt': ['ratcheting', 'chattering'],
#  "'aceelnrsu": ["laurence's", "cerulean's"],
#  "'aeimnrssu": ["suriname's", "aneurism's", "sumerian's"],
#  "'aacorsttu": ["autocrat's", "actuator's"],
#  "'aeeinnstv": ["aventine's", "venetian's"],
#  'aeiilorsst': ['solitaires', 'solitaries'],
#  "'adeilsttu": ["altitude's", "latitude's"],
#  'aeeiprsstt': ['tapestries', 'striptease'],
#  'acdeiimnot': ['decimation', 'medication'],
#  "'aaeiprsst": ["aspirate's", "parasite's"],
#  'adeehilprs': ['leadership', 'dealership'],
#  'aagillmnry': ['marginally', 'alarmingly'],
#  'deeimnorsz': ['sermonized', 'modernizes'],
#  "'abeeknnrs": ["banneker's", "bernanke's"],
#  'deeeloprsv': ['redevelops', 'developers'],
#  'cceennorst': ['connecters', 'reconnects'],
#  'deiinoopst': ['positioned', 'deposition'],
#  'cdegiinnrs': ['rescinding', 'discerning'],
#  "'ceinorsss": ["necrosis's", "ericsson's"],
#  "'aaceinrss": ["canaries's", "cesarian's"],
#  'adeeinrstt': ['reinstated', 'straitened'],
#  'cdeeiinrst': ['indiscreet', 'iridescent'],
#  'eeinprsstt': ['persistent', 'prettiness'],
#  'acgiinnotu': ['cautioning', 'auctioning'],
#  'acdeinoort': ['coordinate', 'decoration'],
#  "'acdelnors": ["colander's", "calderon's"],
#  'cdeiinrstt': ['interdicts', 'distincter'],
#  "'abeirssty": ["sybarite's", "bestiary's"],
#  'aaginnostt': ['antagonist', 'stagnation'],
#  "'addlnoosw": ["download's", "woodland's"],
#  'adeilpsttu': ['stipulated', 'platitudes'],
#  'aeehilrstt': ['earthliest', 'stealthier'],
#  'cefgiinrty': ['rectifying', 'certifying'],
#  'eimnoprstu': ['importunes', 'resumption'],
#  "'aegilnrst": ["triangle's", "integral's"],
#  'cdeinorstu': ['introduces', 'reductions'],
#  'accehimsst': ['schematics', 'catechisms'],
#  'aeehinrsst': ['earthiness', 'heartiness'],
#  "'ailosttty": ["totality's", "tolyatti's"],
#  "'acillosst": ["callisto's", "castillo's"],
#  'eiimnoprss': ['impression', 'permission'],
#  "'adehoorst": ["dorothea's", "theodora's"],
#  'ceginnorsv': ['conversing', 'conserving'],
#  'cdeemoprss': ['compressed', 'decompress'],
#  "'adehlnsst": ["stendhal's", "shetland's"],
#  'eeiilnrst': ['listerine', 'resilient'],
#  'adeinrsst': ['streisand', 'tardiness'],
#  'cdeeoprru': ['reproduce', 'procedure'],
#  "'ehlorsst": ["hostler's", "holster's"],
#  'ginoprstu': ['sprouting', 'posturing'],
#  'egiimmnrs': ['immersing', 'simmering'],
#  'acdehnstu': ['unscathed', 'staunched'],
#  'acdeeimst': ['decimates', 'medicates'],
#  'aeinnrstt': ['intranets', 'transient'],
#  "'eehnorsw": ["nowhere's", "erewhon's"],
#  'aeekorstv': ['takeovers', 'overtakes'],
#  'adegginnr': ['gardening', 'deranging'],
#  'aeelprstt': ['saltpeter', 'saltpetre'],
#  'deflnoruw': ['underflow', 'wonderful'],
#  'aeilmsttu': ['stimulate', 'mutilates'],
#  "'aacellps": ["capella's", "laplace's"],
#  "'bdemoors": ["bedroom's", "boredom's"],
#  'acegilnns': ['cleansing', 'cleanings'],
#  "'eiknrstt": ["knitter's", "trinket's"],
#  'ceilnorsu': ['inclosure', 'cornelius'],
#  'aceginrrt': ['retracing', 'cratering', 'terracing'],
#  'deeinrsst': ['residents', 'tiredness', 'dissenter'],
#  "'aaegstwy": ["getaway's", "gateway's"],
#  'aginpprst': ['trappings', 'strapping'],
#  'aeeegnrst': ['teenagers', 'generates'],
#  'ceeiprsst': ['tricepses', 'precisest'],
#  'adeeinprt': ['pertained', 'repainted'],
#  'adeeenrtv': ['venerated', 'enervated'],
#  'bdeeggrsu': ['begrudges', 'debuggers'],
#  'aeegilnnt': ['eglantine', 'inelegant'],
#  'ghilopstt': ['spotlight', 'stoplight'],
#  'cdeinostu': ['seduction', 'suctioned'],
#  "'cenorstu": ["counter's", "recount's"],
#  'behilprsu': ['publisher', 'republish'],
#  'enorrstuv': ['overturns', 'turnovers'],
#  'deeeloprv': ['redevelop', 'developer'],
#  'cehinopst': ['phonetics', 'ctesiphon'],
#  'egginrstu': ['gesturing', 'grungiest'],
#  "'celmnoss": ["clemson's", "clemons's"],
#  "'behirrst": ["birther's", "rebirth's"],
#  'adeelnrtu': ['unaltered', 'unrelated'],
#  'aeilnorst': ['relations', 'orientals'],
#  'adeginrrw': ['redrawing', 'rewarding'],
#  "'beinrstu": ["tribune's", "turbine's"],
#  'aceilmnsu': ['calumnies', 'masculine'],
#  "'aeginrst": ["ingrate's", "granite's"],
#  "'aeimnors": ["romaine's", "moraine's"],
#  'aadeilstv': ['salivated', 'validates'],
#  'cdeinortu': ['introduce', 'reduction'],
#  'aeeilnpst': ['penalties', 'palestine'],
#  'abghinorr': ['abhorring', 'harboring'],
#  'aeghnopst': ['heptagons', 'pathogens'],
#  "'eenprsss": ["serpens's", "spenser's"],
#  'aeimnnost': ['minnesota', 'nominates'],
#  'acddeeimt': ['medicated', 'decimated'],
#  "'aalmnosy": ["layamon's", "anomaly's"],
#  'eiinopstt': ['pointiest', 'petitions'],
#  "'aeimnrst": ["minaret's", "raiment's"],
#  'cdeiorrst': ['directors', 'creditors'],
#  "'eelrsstw": ["swelter's", "wrestle's"],
#  "'aacclrsu": ["accrual's", "caracul's"],
#  'aeghilnrt': ['haltering', 'lathering', 'earthling'],
#  'achiinrst': ['christina', 'christian'],
#  "'belmmrsu": ["brummel's", "mumbler's"],
#  'cdeiirstu': ['crudities', 'diuretics'],
#  "'belmrstu": ["tumbrel's", "tumbler's"],
#  'ceefiirst': ['certifies', 'rectifies'],
#  "'aeeglnss": ["senegal's", "angeles's"],
#  "'ceorsssu": ["sucrose's", "croesus's"],
#  'aeeiilrst': ['realities', 'israelite'],
#  'ccdeeehkr': ['checkered', 'rechecked'],
#  'egiinprrs': ['springier', 'reprising', 'respiring'],
#  "'adeegnrs": ["grandee's", "grenade's"],
#  'cdeeirttu': ['certitude', 'rectitude'],
#  "'aaeilrsv": ["valarie's", "valeria's"],
#  "'aeilmnns": ["melanin's", "lineman's"],
#  "'abelorst": ["alberto's", "latrobe's"],
#  'degiinnst': ['indigents', 'destining'],
#  'deeefmnrt': ['fermented', 'deferment'],
#  "'aenorsst": ["treason's", "senator's"],
#  "'beensstu": ["subteen's", "steuben's"],
#  "'aelnrstu": ["laurent's", "renault's", "neutral's"],
#  "'eforrsst": ["forster's", "forrest's"],
#  "'beilrsst": ["bristle's", "blister's"],
#  'adeeeglrv': ['everglade', 'leveraged'],
#  'aeghiknnr': ['harkening', 'hankering'],
#  'aceinnsst': ['incessant', 'instances'],
#  'abddeiors': ['broadside', 'sideboard'],
#  'aeehirstt': ['heartiest', 'earthiest'],
#  'aceennrst': ['entrances', 'renascent'],
#  'adeeggrst': ['staggered', 'raggedest'],
#  'beffginru': ['rebuffing', 'buffering'],
#  'abeeginrv': ['bereaving', 'beavering'],
#  'accehimst': ['schematic', 'catechism'],
#  'eehoorsvw': ['whosoever', 'howsoever'],
#  'aehimpsst': ['steamship', 'shipmates'],
#  "'cehilnos": ["nichole's", "helicon's"],
#  'aeeintttv': ['attentive', 'tentative'],
#  "'aerssttw": ["swatter's", "stewart's"],
#  "'aaijnstu": ["tijuana's", "juanita's"],
#  "'aelrsstw": ["wastrel's", "walters's"],
#  'ceoprrrsu': ['procurers', 'precursor'],
#  'aeilnssst': ['stainless', 'saltiness'],
#  "'aceimnrs": ["carmine's", "crimean's"],
#  "'aelorsvy": ["layover's", "overlay's"],
#  "'aacdhnrs": ["chandra's", "handcar's"],
#  'ceiimorst': ['eroticism', 'isometric'],
#  'eeoprssss': ['repossess', 'espressos'],
#  'aceginrst': ['recasting', 'caterings'],
#  'abcegimnr': ['cambering', 'embracing'],
#  'eefiisstt': ['feistiest', 'testifies'],
#  'aabceilrt': ['calibrate', 'bacterial'],
#  'egiilsttz': ['stieglitz', 'glitziest'],
#  'aacinorst': ['croatians', 'raincoats'],
#  "'acinostu": ["caution's", "auction's"],
#  "'aeprsstu": ["pasteur's", "pasture's"],
#  'eeimprsss': ['impresses', 'premisses'],
#  'deiooprst': ['depositor', 'droopiest'],
#  "'acehrstt": ["ratchet's", "chatter's"],
#  'agilnrstt': ['rattlings', 'startling'],
#  'efhiorstt': ['fortieths', 'frothiest'],
#  'aegilnsst': ['slangiest', 'tasseling'],
#  "'eggilrsw": ["wriggle's", "wiggler's"],
#  "'acdemnos": ["caedmon's", "macedon's"],
#  'deehnorst': ['shortened', 'dethrones'],
#  'agillnott': ['totalling', 'allotting'],
#  "'adellnrs": ["darnell's", "randell's"],
#  'ceeilnost': ['elections', 'selection'],
#  'cceennort': ['connecter', 'reconnect'],
#  'aeinprrst': ['transpire', 'terrapins'],
#  'eeforrsst': ['reforests', 'foresters'],
#  'adegmoprr': ['deprogram', 'programed'],
#  "'eeffjrsy": ["jeffery's", "jeffrey's"],
#  "'abegilns": ["bengali's", "algenib's", "belgian's"],
#  "'aeennstt": ["annette's", "nanette's"],
#  'deeiinsst': ['destinies', 'densities'],
#  'adeginprt': ['predating', 'departing'],
#  'cdeenorsv': ['conserved', 'conversed'],
#  'aceelnrss': ['cleansers', 'clearness'],
#  'eginorrst': ['resorting', 'restoring'],
#  'aenoopsst': ['soapstone', 'teaspoons'],
#  "'defiilns": ["infidel's", "infield's"],
#  'abeeilrst': ['liberates', 'beastlier', 'bleariest'],
#  "'aelprstt": ["platter's", "prattle's"],
#  'addlnoosw': ['woodlands', 'downloads'],
#  'eeinrsstt': ['triteness', 'interests'],
#  "'adlnoors": ["orlando's", "rolando's"],
#  "'aegllrsy": ["gallery's", "allergy's"],
#  'aeinnosst': ['estonians', 'sensation'],
#  'aefhilsst': ['faithless', 'flashiest'],
#  'aiinnortu': ['urination', 'ruination'],
#  'ceehiknrt': ['thickener', 'kitchener'],
#  "'aaemnsst": ["eastman's", "smetana's"],
#  "'ehiknrst": ["thinker's", "rethink's"],
#  "'aacflrst": ["fractal's", "flatcar's"],
#  "'adeimrrs": ["admirer's", "married's"],
#  'ccdeenort': ['concerted', 'concreted'],
#  "'dhimorsu": ["rhodium's", "humidor's"],
#  'aeehorrsv': ['overhears', 'overshare'],
#  "'acckosss": ["cossack's", "cassock's"],
#  "'aeilnost": ["toenail's", "elation's"],
#  'aacdeemrt': ['macerated', 'demarcate'],
#  'aceginnrt': ['cantering', 'recanting'],
#  'aacelnrst': ['ancestral', 'lancaster'],
#  'acilmnopt': ['compliant', 'complaint'],
#  "'aenoprss": ["pearson's", "persona's"],
#  'aeinrsstt': ['resistant', 'straitens'],
#  "'einprrst": ["reprint's", "printer's"],
#  'adeeginrr': ['grenadier', 'rereading'],
#  'aginoprrt': ['parroting', 'prorating'],
#  'adeforrtw': ['afterword', 'waterford'],
#  "'ehoorsst": ["hooters's", "shooter's"],
#  "'aaadmnrs": ["narmada's", "ramadan's"],
#  'aceinsstt': ['scantiest', 'tacitness', 'cattiness'],
#  "'abdeirss": ["sidebar's", "seabird's"],
#  'aegilmnnt': ['alignment', 'lamenting'],
#  'aaceilrsv': ['cavalries', 'cavaliers'],
#  'adefilnot': ['deflation', 'defoliant'],
#  "'eenprsst": ["present's", "serpent's"],
#  'eeilnrsst': ['listeners', 'reenlists'],
#  "'aceelnrs": ["cleaner's", "carlene's"],
#  'deeginrss': ['designers', 'redesigns'],
#  "'bbcelors": ["cobbler's", "clobber's"],
#  "'aeilrrst": ["retrial's", "trailer's"],
#  'ceoorstuu': ['courteous', 'outsource'],
#  "'acinosss": ["cassino's", "caisson's"],
#  "'acinopst": ["pontiac's", "caption's"],
#  'eehlnopty': ['telephony', 'polythene'],
#  'beginrttu': ['buttering', 'rebutting'],
#  "'deinssty": ["destiny's", "density's"],
#  "'aaillmns": ["manilla's", "alnilam's"],
#  'aeeilmnnt': ['lineament', 'alinement'],
#  "'eghilnss": ["english's", "shingle's"],
#  'eghiilnrs': ['hirelings', 'relishing'],
#  "'aeehrstt": ["theatre's", "theater's"],
#  "'acdemors": ["mercado's", "comrade's"],
#  'acdeiiprt': ['pediatric', 'patricide'],
#  'acehinrru': ['hurricane', 'raunchier'],
#  'aaceinrst': ['sectarian', 'ascertain', 'cartesian'],
#  "'acginrsv": ["craving's", "carving's"],
#  "'ceeilnss": ["silence's", "license's"],
#  'adeemnrst': ['tradesmen', 'smartened'],
#  "'aceilprs": ["replica's", "caliper's"],
#  'adeinostt': ['stationed', 'antidotes'],
#  'efginorst': ['foresting', 'fostering'],
#  'acgillnor': ['collaring', 'carolling'],
#  'cdegiinrt': ['directing', 'crediting'],
#  "'aaimnors": ["mariano's", "romania's"],
#  'aginorsty': ['signatory', 'gyrations'],
#  'adeginprv': ['pervading', 'depraving'],
#  'eeloprsty': ['proselyte', 'polyester'],
#  'acefirstt': ['trifectas', 'craftiest'],
#  'acdeinotu': ['education', 'auctioned', 'cautioned'],
#  "'ceiklnrs": ["crinkle's", "clinker's"],
#  "'ggiinnss": ["signing's", "singing's"],
#  "'deerrsss": ["dresser's", "redress's"],
#  "'ceilpprs": ["clipper's", "cripple's"],
#  'acghinnst': ['snatching', 'stanching'],
#  'degiinnnt': ['intending', 'indenting'],
#  "'bdenorsu": ["rebound's", "bounder's"],
#  'cdeeirstt': ['directest', 'trisected'],
#  "'acdeilms": ["decimal's", "medical's"],
#  'bdennrsuu': ['sunburned', 'unburdens'],
#  'bdelloors': ['doorbells', 'bordellos'],
#  'acdellops': ['collapsed', 'scalloped'],
#  'deinorssw': ['wordiness', 'rowdiness'],
#  "'ghnosstu": ["shotgun's", "gunshot's"],
#  "'abeillrs": ["braille's", "liberal's"],
#  "'aelnorss": ["orleans's", "salerno's"],
#  "'acehilms": ["michael's", "micheal's"],
#  'cdeginnos': ['seconding', 'consigned'],
#  "'adeelnrs": ["leander's", "darlene's"],
#  'aegimnrsu': ['measuring', 'geraniums'],
#  'degimnrru': ['murdering', 'demurring'],
#  'ceeinorst': ['erections', 'secretion'],
#  "'aaimnrst": ["martina's", "martian's"],
#  'aceeinnrt': ['ancienter', 'nectarine'],
#  "'deiopsst": ["deposit's", "topside's"],
#  'aeeimsstt': ['steamiest', 'estimates'],
#  'aceilnost': ['sectional', 'coastline'],
#  "'aceerrst": ["terrace's", "caterer's"],
#  'aeeilrstt': ['statelier', 'literates'],
#  "'eelrsstt": ["trestle's", "settler's"],
#  'adehioprt': ['atrophied', 'aphrodite'],
#  'aegimnrst': ['streaming', 'emigrants', 'mastering'],
#  'deginnrsu': ['undersign', 'sundering'],
#  'adeenrstu': ['sauntered', 'denatures'],
#  "'einoprst": ["protein's", "pointer's"],
#  "'acehoprs": ["poacher's", "pechora's"],
#  'egiilnnst': ['enlisting', 'tinseling', 'listening'],
#  'cdeefiirt': ['rectified', 'certified'],
#  'acegilnpr': ['parceling', 'replacing'],
#  'aeimorstz': ['amortizes', 'atomizers'],
#  'efhiisstt': ['fetishist', 'shiftiest'],
#  "'aaclrsvy": ["cavalry's", "calvary's"],
#  "'deilorss": ["deloris's", "soldier's"],
#  'adeilsttu': ['latitudes', 'altitudes'],
#  "'aekosttu": ["outtake's", "takeout's"],
#  'aceinosst': ['cessation', 'canoeists'],
#  "'aelmprst": ["templar's", "trample's"],
#  'flnoopssu': ['spoonfuls', 'spoonsful'],
#  'eeilmnost': ['milestone', 'limestone'],
#  'acginnopy': ['poignancy', 'canopying'],
#  "'aabhistt": ["tabitha's", "habitat's"],
#  'aceinorst': ['creations', 'reactions'],
#  "'acemnors": ["cameron's", "romance's"],
#  'giinnprst': ['sprinting', 'printings'],
#  'egiilnrsv': ['silvering', 'slivering'],
#  "'acdeilst": ["citadel's", "dialect's"],
#  'aabcfhkls': ['halfbacks', 'flashback'],
#  'emnnooost': ['monotones', 'moonstone'],
#  'aeghnorsv': ['overhangs', 'hangovers'],
#  "'aeorsstt": ["toaster's", "rosetta's"],
#  'aeinrrsst': ['strainers', 'restrains'],
#  'ghinnorsu': ['unhorsing', 'onrushing'],
#  "'abdennrs": ["branden's", "brendan's"],
#  'ehkoorsuw': ['housework', 'workhouse'],
#  "'acehmrrs": ["charmer's", "marcher's"],
#  "'aelprsst": ["plaster's", "psalter's", "stapler's"],
#  "'bdeilrst": ["driblet's", "dilbert's"],
#  'aceelorss': ['casserole', 'escaroles'],
#  'beeioqssu': ['obsequies', 'essequibo'],
#  "'abelrrsw": ["brawler's", "warbler's"],
#  "'eimprsss": ["impress's", "premiss's"],
#  "'belorsst": ["lobster's", "bolster's"],
#  'acdeehrtt': ['chattered', 'ratcheted'],
#  'accehimns': ['mechanics', 'mischance'],
#  'cddeeinrs': ['rescinded', 'discerned'],
#  'aadeiprst': ['disparate', 'aspirated'],
#  "'acilnors": ["conrail's", "clarion's"],
#  "'aaegilrs": ["regalia's", "algeria's"],
#  "'bdeorstu": ["redoubt's", "doubter's"],
#  "'aerrsstt": ["restart's", "starter's"],
#  "'aainrsst": ["tsarina's", "artisan's", "sinatra's"],
#  "'aacelmns": ["manacle's", "alcmena's"],
#  'cdeinnotu': ['unnoticed', 'continued'],
#  'aabdeginr': ['gabardine', 'bargained'],
#  'eeenprrst': ['presenter', 'represent'],
#  "'cceehkrs": ["recheck's", "checker's"],
#  "'eoprsstu": ["posture's", "proteus's"],
#  "'ehmorsst": ["smother's", "thermos's"],
#  'egimnnort': ['remington', 'mentoring'],
#  'aaceglotu': ['coagulate', 'catalogue'],
#  "'efghirst": ["fighter's", "freight's"],
#  'adeiiintt': ['initiated', 'dietitian'],
#  'aaegilnpp': ['lagniappe', 'appealing'],
#  'deiinrsst': ['disinters', 'dirtiness'],
#  'defgiiins': ['dignifies', 'signified'],
#  'aegilnpry': ['replaying', 'parleying'],
#  "'eiknrsst": ["kirsten's", "stinker's", "kristen's"],
#  "'benoorss": ["osborne's", "robeson's"],
#  'addegimnn': ['maddening', 'demanding'],
#  "'aaceirsv": ["avarice's", "caviare's"],
#  'cgiinnoot': ['cognition', 'incognito'],
#  "'aacelmrs": ["caramel's", "carmela's"],
#  "'eprrssuu": ["usurper's", "pursuer's"],
#  "'beinrstt": ["britten's", "bittern's"],
#  'ceginorst': ['escorting', 'corseting'],
#  "'aemrsssu": ["masseur's", "erasmus's"],
#  'aeiinnstu': ['insinuate', 'annuities'],
#  'cegiilnns': ['silencing', 'licensing'],
#  "'dggilnos": ["lodging's", "golding's"],
#  'acegimnrt': ['cremating', 'centigram'],
#  "'aeilnsst": ["saltine's", "salient's"],
#  "'affnorss": ["saffron's", "sarnoff's"],
#  'adeoprrty': ['portrayed', 'predatory'],
#  "'aceelrst": ["treacle's", "electra's"],
#  "'aceorrst": ["reactor's", "creator's"],
#  'defgiinnr': ['friending', 'infringed'],
#  'adeeimrst': ['dreamiest', 'diameters'],
#  'cdeenortu': ['countered', 'recounted'],
#  "'adegilns": ["leading's", "dealing's"],
#  'aginorsst': ['assorting', 'organists'],
#  'aainprsst': ['aspirants', 'partisans'],
#  "'celrstuy": ["cruelty's", "cutlery's"],
#  "'cenoorrs": ["crooner's", "coroner's"],
#  "'eeerrssv": ["reserve's", "reverse's"],
#  'dehinosst': ['dishonest', 'hedonists'],
#  'adejrsstu': ['adjusters', 'readjusts'],
#  'aacorsttu': ['actuators', 'autocrats'],
#  "'adeeisss": ["seaside's", "disease's"],
#  "'abeerstt": ["beretta's", "abetter's"],
#  "'aegimrst": ["ragtime's", "maigret's"],
#  "'aabdimrs": ["barmaid's", "mariadb's"],
#  "'eeimnsss": ["nemesis's", "siemens's"],
#  "'acceinos": ["cocaine's", "oceanic's"],
#  'aegilnrst': ['integrals', 'gnarliest', 'triangles'],
#  'dfgilnnou': ['unfolding', 'foundling'],
#  'aeemnsttt': ['testament', 'statement'],
#  'ceinorstu': ['countries', 'cretinous', 'neurotics'],
#  'aadeipprs': ['appraised', 'disappear'],
#  'aeegnrsst': ['estranges', 'greatness', 'sergeants'],
#  'aillorstt': ['littorals', 'tortillas'],
#  'eeeinnrst': ['internees', 'ernestine'],
#  "'ainoorst": ["ontario's", "oration's"],
#  'adeeisstt': ['stateside', 'steadiest'],
#  "'ceeprsst": ["specter's", "scepter's", "respect's"],
#  'adeeimstt': ['meditates', 'estimated'],
#  "'aahinsst": ["tanisha's", "ashanti's"],
#  "'aenprsst": ["napster's", "pastern's"],
#  'egiimnprs': ['premising', 'simpering'],
#  "'klooostu": ["outlook's", "lookout's"],
#  "'aegopsst": ["gestapo's", "postage's"],
#  "'aprssttu": ["upstart's", "startup's"],
#  "'acehlors": ["chorale's", "cholera's"],
#  'aeelssstt': ['tasteless', 'stateless'],
#  'ceghinort': ['creighton', 'hectoring'],
#  'aghilmort': ['logarithm', 'algorithm'],
#  'adeoprrst': ['teardrops', 'predators'],
#  "'achiinst": ["chaitin's", "chianti's"],
#  "'aaegmnst": ["magenta's", "magnate's"],
#  'aeeginnrt': ['tangerine', 'argentine'],
#  "'aennorss": ["rosanne's", "roseann's"],
#  "'ainrsstt": ["transit's", "tristan's"],
#  "'egilmmns": ["lemming's", "memling's"],
#  'aeeenrstv': ['enervates', 'venerates'],
#  "'celorstu": ["coulter's", "cloture's"],
#  "'abeirstt": ["terabit's", "biretta's"],
#  'aabdlorrs': ['labradors', 'larboards'],
#  'acddeenst': ['decadents', 'descanted'],
#  "'eelprssu": ["repulse's", "slurpee's"],
#  'aeefmnors': ['forenames', 'freemason'],
#  'agiilnost': ['isolating', 'intaglios'],
#  "'achissty": ["chasity's", "scythia's"],
#  "'aeginnst": ["gentian's", "antigen's"],
#  "'aeilnors": ["aileron's", "loraine's"],
#  'aeegillrs': ['galleries', 'allergies'],
#  "'acelmors": ["carmelo's", "marcelo's"],
#  "'ceefprst": ["perfect's", "prefect's"],
#  'aabcdkrsw': ['drawbacks', 'backwards'],
#  "'abeilors": ["alberio's", "albireo's"],
#  'ceeginptx': ['expecting', 'excepting'],
#  "'eoprsstt": ["spotter's", "protest's"],
#  "'aegmnost": ["montage's", "magneto's", "megaton's"],
#  "'aceehrst": ["hectare's", "cheater's", "teacher's"],
#  'eeilnosss': ['noiseless', 'lionesses'],
#  "'aehmrsst": ["hamster's", "amherst's"],
#  "'ahmnopst": ["hampton's", "phantom's"],
#  'ceeeilstv': ['electives', 'selective'],
#  "'aceilrst": ["recital's", "article's"],
#  'aaeiprsst': ['parasites', 'aspirates'],
#  'ceenorssv': ['converses', 'conserves'],
#  "'ceikrsst": ["rickets's", "sticker's"],
#  "'aaenpsst": ["peasant's", "anapest's"],
#  "'aceelnsv": ["valence's", "enclave's"],
#  "'aeeijnns": ["jeanine's", "jeannie's"],
#  "'aeinrrst": ["trainer's", "terrain's"],
#  'eeginrrsv': ['reversing', 'reserving'],
#  'acillopty': ['optically', 'topically'],
#  'aegmoprrr': ['reprogram', 'programer'],
#  'aeeilrstv': ['versatile', 'relatives'],
#  'accgikln': ['clacking', 'cackling'],
#  'aehisstt': ['atheists', 'hastiest'],
#  "'adenrss": ["sander's", "andres's"],
#  'aeeilrst': ['earliest', 'ateliers'],
#  'aeehrstw': ['wreathes', 'weathers'],
#  'aeeglnrs': ['generals', 'enlarges'],
#  'cemprstu': ['spectrum', 'crumpets'],
#  'aeghnopt': ['heptagon', 'pathogen'],
#  'deeinrst': ['inserted', 'resident', 'dniester', 'trendies', 'nerdiest'],
#  'adeeirst': ['steadier', 'readiest'],
#  "'ceinsst": ["incest's", "insect's"],
#  'eginoprs': ['reposing', 'spongier'],
#  'ceefprst': ['prefects', 'perfects'],
#  'aillortt': ['littoral', 'tortilla'],
#  "'aelnors": ["lorena's", "elanor's", "lenora's", "elnora's", "loaner's"],
#  'cdinostu': ['discount', 'conduits'],
#  'deiinost': ['sedition', 'editions'],
#  "'aegorst": ["garote's", "ortega's", "tagore's"],
#  "'aegimrs": ["margie's", "mirage's"],
#  "'agnorss": ["sargon's", "sarong's"],
#  "'eehrsst": ["hester's", "esther's"],
#  'adehlnst': ['shetland', 'stendhal'],
#  'aeerrssu': ['reassure', 'erasures'],
#  'deeerrsv': ['reversed', 'reserved'],
#  "'beorsst": ["osbert's", "strobe's", "sorbet's"],
#  'eeinrstu': ['reunites', 'retinues'],
#  'ceirrssu': ['scurries', 'cruisers'],
#  "'eelnors": ["lenore's", "lorene's"],
#  "'acellrs": ["cellar's", "caller's", "recall's"],
#  'efhiinrs': ['refinish', 'finisher'],
#  'aenprstt': ['transept', 'patterns'],
#  'bdenorsu': ['rebounds', 'suborned', 'bounders'],
#  'abcdeirs': ['carbides', 'ascribed'],
#  'adddeemn': ['maddened', 'demanded'],
#  'adeoprrt': ['parroted', 'teardrop', 'predator', 'prorated'],
#  'ciiknpst': ['stickpin', 'nitpicks'],
#  'cenorstu': ['counters', 'construe', 'recounts', 'trounces'],
#  "'acenrst": ["cretan's", "trance's", "nectar's", "canter's"],
#  "'beffrsu": ["rebuff's", "buffer's"],
#  'aerrsstt': ['starters', 'restarts'],
#  'egilnorw': ['roweling', 'lowering'],
#  'addeeprt': ['predated', 'departed'],
#  'klooostu': ['outlooks', 'lookouts'],
#  'ehlorsst': ['holsters', 'hostlers'],
#  'aegilnrs': ['slangier', 'salinger'],
#  "'aalmnsu": ["alumna's", "manual's"],
#  "'adegnrs": ["gander's", "danger's", "garden's"],
#  'agimnrst': ['smarting', 'migrants'],
#  'einorssu': ['neurosis', 'resinous'],
#  "'aeglnrs": ["angler's", "erlang's"],
#  'bdegiint': ['betiding', 'debiting'],
#  'adeehlrt': ['haltered', 'lathered'],
#  'eegginnr': ['greening', 'reneging'],
#  'eegilnrv': ['reveling', 'levering'],
#  "'eipprst": ["tipper's", "trippe's"],
#  'deeforst': ['fostered', 'forested', 'deforest'],
#  "'eehprss": ["herpes's", "sphere's"],
#  'deeilnst': ['enlisted', 'listened', 'tinseled'],
#  'aeinrrst': ['retrains', 'strainer', 'restrain', 'trainers', 'terrains'],
#  'defgiiln': ['defiling', 'fielding'],
#  "'eillnst": ["lentil's", "lintel's"],
#  'adeilotv': ['violated', 'dovetail'],
#  'ddeilnsw': ['dwindles', 'swindled'],
#  'cdeiprst': ['predicts', 'scripted'],
#  'aghinssw': ['washings', 'swashing'],
#  "'cceilrs": ["cleric's", "circle's"],
#  'acginost': ['agnostic', 'coasting', 'coatings'],
#  'adeerrst': ['retreads', 'serrated', 'arrested'],
#  'adeinrtt': ['nitrated', 'andretti'],
#  'deeginrs': ['redesign', 'resigned', 'designer'],
#  "'cirsstu": ["citrus's", "curtis's", "rustic's"],
#  'ceelorst': ['electors', 'selector'],
#  'egilnrst': ['sterling', 'ringlets'],
#  "'adefirs": ["frieda's", "freida's"],
#  'acdeenrt': ['recanted', 'cantered', 'decanter'],
#  "'acdelrs": ["calder's", "cradle's"],
#  'aceinnst': ['canniest', 'ancients', 'instance'],
#  'deiopsst': ['deposits', 'topsides'],
#  'aegillps': ['pillages', 'spillage'],
#  "'acilnsu": ["lucian's", "alcuin's"],
#  'aceorrst': ['reactors', 'creators'],
#  "'ainsstu": ["unitas's", "austin's"],
#  "'aekrsst": ["skater's", "streak's"],
#  'aeeeprrt': ['repeater', 'repartee'],
#  'aelorsvy': ['layovers', 'overlays'],
#  "'aadenns": ["deanna's", "andean's"],
#  'abgilnst': ['blasting', 'stabling'],
#  'adeisstt': ['staidest', 'distaste'],
#  'cenrsstu': ['curtness', 'encrusts'],
#  "'aderrsw": ["reward's", "drawer's", "warder's"],
#  'cdeehipr': ['decipher', 'ciphered'],
#  "'ceeiprs": ["recipe's", "pierce's"],
#  'aeeimrst': ['emirates', 'steamier'],
#  'acehnsst': ['stanches', 'snatches', 'chastens'],
#  'deeimprs': ['premised', 'simpered'],
#  'ceikorst': ['rockiest', 'stockier'],
#  "'aadilns": ["danial's", "dalian's"],
#  "'aeiprss": ["persia's", "spirea's", "praise's"],
#  "'aailrst": ["altair's", "lariat's"],
#  'adeemrst': ['mastered', 'streamed'],
#  "'aegnrrs": ["ranger's", "garner's"],
#  'acdilnor': ['alcindor', 'ironclad'],
#  "'cefhist": ["fetich's", "fichte's"],
#  "'acelosv": ["alcove's", "coeval's"],
#  'ceefhist': ['fetiches', 'chiefest'],
#  'bdeilrsu': ['rebuilds', 'builders'],
#  "'aeersst": ["easter's", "teaser's", "teresa's"],
#  'cdeiorsv': ['divorces', 'discover'],
#  'beghinrt': ['berthing', 'brighten'],
#  'aginorst': ['organist', 'roasting'],
#  "'eiklnsw": ["welkin's", "winkle's"],
#  "'bekoors": ["brooke's", "booker's"],
#  "'cnosstu": ["tuscon's", "tucson's"],
#  "'deinnos": ["dionne's", "donnie's"],
#  'aeimnrsu': ['sumerian', 'aneurism', 'suriname'],
#  'acdehnst': ['stanched', 'snatched'],
#  'adeeilnt': ['dateline', 'entailed'],
#  'aceilsst': ['alcestis', 'elastics', 'scaliest'],
#  'aegilmnr': ['germinal', 'malinger'],
#  'adeilort': ['tailored', 'idolater'],
#  'aaegsssu': ['sausages', 'assuages'],
#  'aeilnsst': ['saltines', 'salients'],
#  'aceilprs': ['replicas', 'calipers'],
#  'ggiilnns': ['slinging', 'singling'],
#  "'aehrstt": ["hatter's", "threat's"],
#  'bcehrstu': ['butchers', 'schubert'],
#  'eeinrstv': ['reinvest', 'nerviest'],
#  'eeerrssv': ['reverses', 'reserves'],
#  "'aaglnos": ["angola's", "analog's"],
#  'adeinrst': ['strained', 'randiest'],
#  'aceorstv': ['overcast', 'overacts'],
#  "'eenrsst": ["sterne's", "ernest's"],
#  'adeelpry': ['replayed', 'parleyed'],
#  'aegginnr': ['angering', 'enraging'],
#  'abeeilns': ['baseline', 'balinese'],
#  'cehinopt': ['pinochet', 'phonetic'],
#  'aainrsst': ['artisans', 'tsarinas'],
#  'adeegnrs': ['deranges', 'grenades', 'grandees'],
#  "'eehrssy": ["heresy's", "hersey's"],
#  'ceoprstt': ['prescott', 'protects'],
#  "'aelnpst": ["platen's", "planet's"],
#  'acginrsv': ['cravings', 'carvings'],
#  'ceeinnss': ['incenses', 'niceness'],
#  "'ggiknos": ["gingko's", "ginkgo's"],
#  'acgilnps': ['scalping', 'clasping'],
#  'aegilnrt': ['alerting', 'relating', 'altering', 'triangle', 'integral'],
#  "'definrs": ["finder's", "friend's"],
#  'egiimnrt': ['meriting', 'mitering'],
#  "'eorrsst": ["resort's", "torres's", "sorter's", "roster's"],
#  'adelorst': ['lodestar', 'leotards'],
#  'ceegnorv': ['converge', 'congreve'],
#  "'eilnors": ["lenoir's", "elinor's"],
#  'bdeeggru': ['begrudge', 'debugger'],
#  'adeeprst': ['pederast', 'predates'],
#  'deinoops': ['poseidon', 'poisoned'],
#  "'aehprss": ["sharpe's", "seraph's", "sherpa's", "phrase's"],
#  "'aersstu": ["seurat's", "atreus's"],
#  "'alnosst": ["salton's", "alston's"],
#  "'acginrs": ["racing's", "caring's"],
#  'ceinorss': ['ericsson', 'necrosis'],
#  'aceilmsx': ['exclaims', 'climaxes'],
#  "'aelmrst": ["armlet's", "martel's"],
#  "'adimnos": ["damion's", "domain's"],
#  'egoprrsu': ['regroups', 'groupers'],
#  "'aceprss": ["scrape's", "parsec's"],
#  'deeelnss': ['lessened', 'needless'],
#  "'airsstt": ["artist's", "strait's"],
#  'aaegstwy': ['gateways', 'getaways'],
#  "'anoprst": ["patron's", "tarpon's"],
#  "'abelstt": ["tablet's", "battle's"],
#  'aceipsst': ['spaciest', 'escapist'],
#  'aeegnrsv': ['engraves', 'avengers'],
#  'abcdeemr': ['cambered', 'embraced'],
#  'deoprstu': ['postured', 'proudest', 'sprouted'],
#  "'aaimnrs": ["marian's", "marina's", "airman's", "armani's"],
#  'ceginotv': ['vietcong', 'coveting'],
#  'defhiins': ['fiendish', 'finished'],
#  "'acnorst": ["carnot's", "cantor's", "carton's"],
#  "'amnoors": ["maroon's", "romano's"],
#  'bbbgilno': ['bobbling', 'blobbing'],
#  'dginnosu': ['sounding', 'undoings'],
#  'aaginrrs': ['srinagar', 'arraigns'],
#  'addeegnr': ['deranged', 'gardened'],
#  "'enosstw": ["weston's", "townes's"],
#  'ceirrstu': ['recruits', 'crustier'],
#  'ainprstu': ['puritans', 'rasputin'],
#  "'elrsstu": ["result's", "ulster's", "rustle's", "lustre's", "luster's"],
#  "'egginrs": ["ginger's", "nigger's"],
#  'eeimnotz': ['monetize', 'timezone'],
#  'eefnortw': ['forewent', 'freetown'],
#  'cdeoprru': ['producer', 'procured'],
#  'eilmpsst': ['misspelt', 'simplest'],
#  'adeegnrr': ['garnered', 'gardener'],
#  "'ceinors": ["corine's", "enrico's"],
#  'acehrstt': ['ratchets', 'chatters'],
#  'ailmrstu': ['altruism', 'muralist'],
#  "'abilnos": ["albion's", "albino's"],
#  'dellorst': ['drollest', 'strolled'],
#  "'eiprsst": ["priest's", "sprite's", "stripe's"],
#  'adfhlnsu': ['handsful', 'handfuls'],
#  "'belsstu": ["bustle's", "sublet's"],
#  'eiorrsst': ['roisters', 'sorriest', 'resistor'],
#  'aceehrst': ['cheaters', 'teachers', 'hectares'],
#  'aekosttu': ['outtakes', 'stakeout', 'takeouts'],
#  'aelprstt': ['splatter', 'prattles', 'platters'],
#  'adegilns': ['signaled', 'dealings'],
#  "'deinnst": ["indent's", "dentin's"],
#  'eeelprss': ['sleepers', 'peerless'],
#  'acdeilst': ['dialects', 'citadels'],
#  'ceilpprs': ['cripples', 'clippers'],
#  "'elorsuv": ["louver's", "velour's", "louvre's"],
#  "'aaikmst": ["tamika's", "katmai's"],
#  'cenosstu': ['contuses', 'countess'],
#  'acdeerrt': ['retraced', 'terraced', 'cratered'],
#  'aeghinrs': ['hearings', 'shearing'],
#  "'enrrstu": ["return's", "turner's"],
#  'ceenorsv': ['conserve', 'converse'],
#  'accdesuu': ['caucused', 'caduceus'],
#  "'aderrst": ["trader's", "retard's"],
#  "'aaeglns": ["angela's", "galena's"],
#  'egginorr': ['rogering', 'reorging'],
#  "'aaprsst": ["sparta's", "satrap's"],
#  "'alostuy": ["layout's", "outlay's"],
#  "'abehrst": ["breath's", "bather's", "bertha's"],
#  "'efillrs": ["filler's", "refill's"],
#  'ceeilnss': ['licenses', 'silences'],
#  'aprssttu': ['startups', 'upstarts'],
#  "'adehlns": ["handel's", "handle's"],
#  'deilmnss': ['mildness', 'mindless'],
#  'ailottty': ['totality', 'tolyatti'],
#  'bdelloor': ['bordello', 'doorbell'],
#  "'efirsst": ["sifter's", "strife's"],
#  'aeeirstt': ['treatise', 'treaties', 'iterates', 'teariest'],
#  'acenrstu': ['centaurs', 'etruscan'],
#  "'beginos": ["biogen's", "boeing's"],
#  'eilmntuy': ['untimely', 'minutely'],
#  'eenprsst': ['pertness', 'presents', 'serpents'],
#  'aceilrst': ['articles', 'recitals'],
#  "'acorsst": ["castor's", "castro's", "costar's"],
#  "'adlnpsu": ["upland's", "dunlap's"],
#  'agiilnrv': ['virginal', 'rivaling'],
#  "'aekmrrs": ["kramer's", "remark's", "marker's"],
#  'afillpsu': ['pailsful', 'pailfuls'],
#  'adeelprs': ['relapsed', 'pleaders'],
#  "'beelrst": ["treble's", "elbert's"],
#  "'efilrst": ["filter's", "trifle's"],
#  'cceinors': ['conciser', 'cornices'],
#  'aehhrsst': ['thrashes', 'harshest'],
#  "'aelrstt": ["rattle's", "latter's"],
#  "'adeinns": ["nadine's", "dannie's", "dianne's"],
#  "'abelmrs": ["ramble's", "marble's"],
#  'aeinprst': ['pertains', 'painters', 'repaints', 'pantries'],
#  'aeeilrsz': ['sleazier', 'realizes'],
#  "'bellosw": ["bowell's", "bellow's"],
#  'aeimortz': ['atomizer', 'amortize'],
#  'aacimnor': ['macaroni', 'marciano'],
#  "'ilmnost": ["milton's", "tomlin's"],
#  'acddeent': ['decadent', 'decanted'],
#  'abdeinrs': ['brandies', 'brandeis'],
#  'aeginrst': ['tasering',
#   'gantries',
#   'angriest',
#   'tangiers',
#   'ingrates',
#   'rangiest'],
#  'aaginssy': ['gainsays', 'assaying'],
#  'ghilnstu': ['sunlight', 'hustling'],
#  'abeiinrs': ['binaries', 'siberian'],
#  "'adeelrs": ["dealer's", "leader's"],
#  "'eorssty": ["oyster's", "storey's"],
#  "'acnorsy": ["crayon's", "cyrano's"],
#  "'aeekmrs": ["kareem's", "remake's"],
#  'aacdensv': ['canvased', 'advances'],
#  'ddeilnps': ['spindled', 'splendid'],
#  'cdeeeptx': ['excepted', 'expected'],
#  "'aelrssv": ["salver's", "slaver's"],
#  "'deinssy": ["sidney's", "disney's"],
#  "'eilostt": ["lottie's", "toilet's"],
#  'aeginnrs': ['earnings', 'grannies'],
#  "'eghhist": ["eighth's", "height's"],
#  "'acilssv": ["vlasic's", "slavic's"],
#  'ehnorssu': ['onrushes', 'unhorses'],
#  'cceeirsv': ['crevices', 'cervices'],
#  'eioprsst': ['prosiest', 'ripostes'],
#  "'adehrst": ["dearth's", "thread's", "hatred's"],
#  'deilnstu': ['insulted', 'unlisted'],
#  'dginorsw': ['drowsing', 'wordings'],
#  "'eenrstu": ["tureen's", "tenure's", "neuter's"],
#  "'beehsst": ["behest's", "thebes's"],
#  'beilrsst': ['blisters', 'bristles'],
#  "'admnosy": ["dynamo's", "monday's"],
#  "'egiorst": ["goitre's", "goiter's"],
#  'aeiprsst': ['traipses', 'raspiest', 'pastries'],
#  'aaenpsst': ['anapests', 'peasants'],
#  'cehiistt': ['itchiest', 'theistic'],
#  "'bnoorss": ["robson's", "osborn's"],
#  "'eginrss": ["signer's", "ingres's", "singer's"],
#  "'aegirst": ["gaiter's", "triage's"],
#  'behirrst': ['birthers', 'rebirths'],
#  "'aailmns": ["animal's", "malian's", "manila's"],
#  "'deenrsv": ["denver's", "vender's"],
#  "'eeggirs": ["reggie's", "geiger's"],
#  'cgimmnsu': ['cummings', 'scumming'],
#  "'abilmsu": ["labium's", "malibu's"],
#  "'aehmnrs": ["herman's", "arnhem's"],
#  'deelprsu': ['repulsed', 'preludes'],
#  "'aehlrst": ["lather's", "halter's"],
#  'abeklnst': ['blankest', 'blankets'],
#  "'addemns": ["demand's", "madden's"],
#  "'belorsw": ["bowler's", "blower's"],
#  'cddeeirt': ['credited', 'directed'],
#  "'eilnpsu": ["lupine's", "lineup's"],
#  'aeggilnr': ['regaling', 'ganglier'],
#  'aaegmnrs': ['semarang', 'managers'],
#  "'ellosvy": ["lovely's", "volley's"],
#  'aginnttu': ['attuning', 'taunting'],
#  'aegginor': ['georgina', 'georgian'],
#  'aehmnors': ['horseman', 'menorahs'],
#  "'ehikrss": ["shrike's", "shriek's"],
#  'aeilnort': ['oriental', 'relation'],
#  "'abginsu": ["ubangi's", "bangui's"],
#  "'aenrrsw": ["warner's", "warren's"],
#  ...}

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
